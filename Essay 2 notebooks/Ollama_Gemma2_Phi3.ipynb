# %%
import ollama # For running LLMs locally
from langchain_community.document_loaders import TextLoader # For loading text documents for use in LLMs
from langchain_community.document_loaders import DirectoryLoader # For loading directories of text documents for use in LLMs
import magic # This is needed for some reason for the DirectoryLoader to work
from ollama import generate
import pandas as pd
import json

# %%
# Do that weird "r" thing because paths are weird in Windows
path = r"C:\Users\MCOB PHD 14\Dropbox\Charlie's Dissertation\Beige Books\test_texts"

# Give it the path and tell it to look for .txt files
loader = DirectoryLoader(path, glob="**/*.txt")

# Read in all the documents from that directory as a list
docs = loader.load()

# %% [markdown]
# # Phi3

# %%
# Import necessary libraries
import json
import pandas as pd

# Set the local model and new prompt for classification
local_model = 'phi3'
prompt_sentiment = 'Label the overall economic sentiment in the following Beige Book text as negative, mixed, or positive. Return the label as a JSON value with a key of "label" and nothing else: '

# Function to get sentiment label for each document
def get_sentiment_label(doc_content):
    # Combine the sentiment prompt with the document content
    full_prompt = f"{prompt_sentiment}\n{doc_content}"
    # Generate the sentiment label using the local model
    result = ollama.generate(model=local_model, prompt=full_prompt, format='json', stream=False, options={'temperature': 0})
    return result

# Possible keys that might hold the sentiment label
label_keys = ["label", "sentiment_label"]

# List to store the data for the DataFrame
data = []

# Total number of documents for progress tracking
total_docs = len(docs)

# Collect sentiment results for each document, with document index and status update
for i, doc in enumerate(docs):
    doc_content = doc.page_content
    result = get_sentiment_label(doc_content)
    
    # Extract the response value from the result
    response_json = result.get('response', '{}')
    # Parse the response JSON if it's a string
    response_data = json.loads(response_json) if isinstance(response_json, str) else response_json
    
    # Extract the sentiment label using the possible keys
    sentiment_label = None
    for key in label_keys:
        if key in response_data:
            sentiment_label = response_data[key]
            break
    
    # If no label was found, set it as 'N/A'
    if sentiment_label is None:
        sentiment_label = 'N/A'
    
    # Append the result to the data list with the document index and content
    data.append({
        "Document Number": i + 1,
        "Document Content": doc_content,
        "Sentiment Label": sentiment_label,
        "Full Result": result
    })

    # Print status update
    print(f"Processed document {i + 1}/{total_docs} - Sentiment Label: {sentiment_label}")

# Create a DataFrame from the data list
df_phi3 = pd.DataFrame(data)

# Print the DataFrame
print(df_phi3)
# Out:
# Processed document 1/200 - Sentiment Label: negative
# Processed document 2/200 - Sentiment Label: mixed
# Processed document 3/200 - Sentiment Label: mixed
# Processed document 4/200 - Sentiment Label: mixed
# Processed document 5/200 - Sentiment Label: mixed
# Processed document 6/200 - Sentiment Label: positive
# Processed document 7/200 - Sentiment Label: positive
# Processed document 8/200 - Sentiment Label: mixed
# Processed document 9/200 - Sentiment Label: mixed
# Processed document 10/200 - Sentiment Label: negative
# Processed document 11/200 - Sentiment Label: negative
# Processed document 12/200 - Sentiment Label: mixed
# Processed document 13/200 - Sentiment Label: positive
# Processed document 14/200 - Sentiment Label: mixed
# Processed document 15/200 - Sentiment Label: negative
# Processed document 16/200 - Sentiment Label: mixed
# Processed document 17/200 - Sentiment Label: mixed
# Processed document 18/200 - Sentiment Label: mixed
# Processed document 19/200 - Sentiment Label: mixed
# Processed document 20/200 - Sentiment Label: negative
# Processed document 21/200 - Sentiment Label: mixed
# Processed document 22/200 - Sentiment Label: mixed
# Processed document 23/200 - Sentiment Label: mixed
# Processed document 24/200 - Sentiment Label: negative
# Processed document 25/200 - Sentiment Label: mixed
# Processed document 26/200 - Sentiment Label: mixed
# Processed document 27/200 - Sentiment Label: mixed
# Processed document 28/200 - Sentiment Label: mixed
# Processed document 29/200 - Sentiment Label: mixed
# Processed document 30/200 - Sentiment Label: mixed
# Processed document 31/200 - Sentiment Label: mixed
# Processed document 32/200 - Sentiment Label: negative
# Processed document 33/200 - Sentiment Label: mixed
# Processed document 34/200 - Sentiment Label: mixed
# Processed document 35/200 - Sentiment Label: negative
# Processed document 36/200 - Sentiment Label: mixed
# Processed document 37/200 - Sentiment Label: mixed
# Processed document 38/200 - Sentiment Label: mixed
# Processed document 39/200 - Sentiment Label: mixed
# Processed document 40/200 - Sentiment Label: negative
# Processed document 41/200 - Sentiment Label: mixed
# Processed document 42/200 - Sentiment Label: mixed
# Processed document 43/200 - Sentiment Label: mixed
# Processed document 44/200 - Sentiment Label: mixed
# Processed document 45/200 - Sentiment Label: mixed
# Processed document 46/200 - Sentiment Label: mixed
# Processed document 47/200 - Sentiment Label: mixed
# Processed document 48/200 - Sentiment Label: mixed
# Processed document 49/200 - Sentiment Label: mixed
# Processed document 50/200 - Sentiment Label: negative
# Processed document 51/200 - Sentiment Label: negative
# Processed document 52/200 - Sentiment Label: mixed
# Processed document 53/200 - Sentiment Label: mixed
# Processed document 54/200 - Sentiment Label: mixed
# Processed document 55/200 - Sentiment Label: mixed
# Processed document 56/200 - Sentiment Label: mixed
# Processed document 57/200 - Sentiment Label: positive
# Processed document 58/200 - Sentiment Label: mixed
# Processed document 59/200 - Sentiment Label: mixed
# Processed document 60/200 - Sentiment Label: mixed
# Processed document 61/200 - Sentiment Label: mixed
# Processed document 62/200 - Sentiment Label: positive
# Processed document 63/200 - Sentiment Label: positive
# Processed document 64/200 - Sentiment Label: mixed
# Processed document 65/200 - Sentiment Label: mixed
# Processed document 66/200 - Sentiment Label: mixed
# Processed document 67/200 - Sentiment Label: mixed
# Processed document 68/200 - Sentiment Label: mixed
# Processed document 69/200 - Sentiment Label: positive
# Processed document 70/200 - Sentiment Label: mixed
# Processed document 71/200 - Sentiment Label: mixed
# Processed document 72/200 - Sentiment Label: mixed
# Processed document 73/200 - Sentiment Label: mixed
# Processed document 74/200 - Sentiment Label: mixed
# Processed document 75/200 - Sentiment Label: positive
# Processed document 76/200 - Sentiment Label: positive
# Processed document 77/200 - Sentiment Label: mixed
# Processed document 78/200 - Sentiment Label: positive
# Processed document 79/200 - Sentiment Label: mixed
# Processed document 80/200 - Sentiment Label: mixed
# Processed document 81/200 - Sentiment Label: mixed
# Processed document 82/200 - Sentiment Label: mixed
# Processed document 83/200 - Sentiment Label: positive
# Processed document 84/200 - Sentiment Label: positive
# Processed document 85/200 - Sentiment Label: mixed
# Processed document 86/200 - Sentiment Label: mixed
# Processed document 87/200 - Sentiment Label: mixed
# Processed document 88/200 - Sentiment Label: positive
# Processed document 89/200 - Sentiment Label: negative
# Processed document 90/200 - Sentiment Label: positive
# Processed document 91/200 - Sentiment Label: mixed
# Processed document 92/200 - Sentiment Label: positive
# Processed document 93/200 - Sentiment Label: positive
# Processed document 94/200 - Sentiment Label: mixed
# Processed document 95/200 - Sentiment Label: mixed
# Processed document 96/200 - Sentiment Label: positive
# Processed document 97/200 - Sentiment Label: positive
# Processed document 98/200 - Sentiment Label: mixed
# Processed document 99/200 - Sentiment Label: mixed
# Processed document 100/200 - Sentiment Label: negative
# Processed document 101/200 - Sentiment Label: negative
# Processed document 102/200 - Sentiment Label: mixed
# Processed document 103/200 - Sentiment Label: positive
# Processed document 104/200 - Sentiment Label: mixed
# Processed document 105/200 - Sentiment Label: negative
# Processed document 106/200 - Sentiment Label: mixed
# Processed document 107/200 - Sentiment Label: mixed
# Processed document 108/200 - Sentiment Label: mixed
# Processed document 109/200 - Sentiment Label: mixed
# Processed document 110/200 - Sentiment Label: mixed
# Processed document 111/200 - Sentiment Label: mixed
# Processed document 112/200 - Sentiment Label: mixed
# Processed document 113/200 - Sentiment Label: positive
# Processed document 114/200 - Sentiment Label: positive
# Processed document 115/200 - Sentiment Label: mixed
# Processed document 116/200 - Sentiment Label: mixed
# Processed document 117/200 - Sentiment Label: positive
# Processed document 118/200 - Sentiment Label: mixed
# Processed document 119/200 - Sentiment Label: mixed
# Processed document 120/200 - Sentiment Label: mixed
# Processed document 121/200 - Sentiment Label: mixed
# Processed document 122/200 - Sentiment Label: mixed
# Processed document 123/200 - Sentiment Label: mixed
# Processed document 124/200 - Sentiment Label: mixed
# Processed document 125/200 - Sentiment Label: mixed
# Processed document 126/200 - Sentiment Label: mixed
# Processed document 127/200 - Sentiment Label: mixed
# Processed document 128/200 - Sentiment Label: mixed
# Processed document 129/200 - Sentiment Label: negative
# Processed document 130/200 - Sentiment Label: mixed
# Processed document 131/200 - Sentiment Label: mixed
# Processed document 132/200 - Sentiment Label: negative
# Processed document 133/200 - Sentiment Label: mixed
# Processed document 134/200 - Sentiment Label: mixed
# Processed document 135/200 - Sentiment Label: mixed
# Processed document 136/200 - Sentiment Label: negative
# Processed document 137/200 - Sentiment Label: mixed
# Processed document 138/200 - Sentiment Label: mixed
# Processed document 139/200 - Sentiment Label: mixed
# Processed document 140/200 - Sentiment Label: negative
# Processed document 141/200 - Sentiment Label: mixed
# Processed document 142/200 - Sentiment Label: mixed
# Processed document 143/200 - Sentiment Label: mixed
# Processed document 144/200 - Sentiment Label: positive
# Processed document 145/200 - Sentiment Label: mixed
# Processed document 146/200 - Sentiment Label: mixed
# Processed document 147/200 - Sentiment Label: mixed
# Processed document 148/200 - Sentiment Label: mixed
# Processed document 149/200 - Sentiment Label: positive
# Processed document 150/200 - Sentiment Label: mixed
# Processed document 151/200 - Sentiment Label: mixed
# Processed document 152/200 - Sentiment Label: positive
# Processed document 153/200 - Sentiment Label: mixed
# Processed document 154/200 - Sentiment Label: positive
# Processed document 155/200 - Sentiment Label: mixed
# Processed document 156/200 - Sentiment Label: mixed
# Processed document 157/200 - Sentiment Label: mixed
# Processed document 158/200 - Sentiment Label: mixed
# Processed document 159/200 - Sentiment Label: mixed
# Processed document 160/200 - Sentiment Label: mixed
# Processed document 161/200 - Sentiment Label: mixed
# Processed document 162/200 - Sentiment Label: mixed
# Processed document 163/200 - Sentiment Label: mixed
# Processed document 164/200 - Sentiment Label: positive
# Processed document 165/200 - Sentiment Label: mixed
# Processed document 166/200 - Sentiment Label: mixed
# Processed document 167/200 - Sentiment Label: mixed
# Processed document 168/200 - Sentiment Label: mixed
# Processed document 169/200 - Sentiment Label: mixed
# Processed document 170/200 - Sentiment Label: positive
# Processed document 171/200 - Sentiment Label: mixed
# Processed document 172/200 - Sentiment Label: positive
# Processed document 173/200 - Sentiment Label: mixed
# Processed document 174/200 - Sentiment Label: mixed
# Processed document 175/200 - Sentiment Label: mixed
# Processed document 176/200 - Sentiment Label: mixed
# Processed document 177/200 - Sentiment Label: positive
# Processed document 178/200 - Sentiment Label: mixed
# Processed document 179/200 - Sentiment Label: mixed
# Processed document 180/200 - Sentiment Label: mixed
# Processed document 181/200 - Sentiment Label: mixed
# Processed document 182/200 - Sentiment Label: mixed
# Processed document 183/200 - Sentiment Label: negative
# Processed document 184/200 - Sentiment Label: mixed
# Processed document 185/200 - Sentiment Label: mixed
# Processed document 186/200 - Sentiment Label: mixed
# Processed document 187/200 - Sentiment Label: mixed
# Processed document 188/200 - Sentiment Label: mixed
# Processed document 189/200 - Sentiment Label: mixed
# Processed document 190/200 - Sentiment Label: mixed
# Processed document 191/200 - Sentiment Label: mixed
# Processed document 192/200 - Sentiment Label: negative
# Processed document 193/200 - Sentiment Label: mixed
# Processed document 194/200 - Sentiment Label: mixed
# Processed document 195/200 - Sentiment Label: mixed
# Processed document 196/200 - Sentiment Label: mixed
# Processed document 197/200 - Sentiment Label: mixed
# Processed document 198/200 - Sentiment Label: negative
# Processed document 199/200 - Sentiment Label: mixed
# Processed document 200/200 - Sentiment Label: negative
#      Document Number                                   Document Content  \
# 0                  1  rates and terms have not eased much . There ar...
# 1                  2  July 15 , 1970 Economic activity in the Fourth...
# 2                  3  wage settlements and over continued upward pre...
# 3                  4  adversely affected by curtailment of Governmen...
# 4                  5  build offshore nuclear generators . Two wareho...
# ..               ...                                                ...
# 195              196  with several Florida ports reporting strong pa...
# 196              197  Beige Book Report : Dallas May 29 , 2024 Summa...
# 197              198  to the sidelines , diving up demand for rental...
# 198              199  significant discounts '' after a long period o...
# 199              200  to the industrial and multifamily segments . C...
#
#     Sentiment Label                                        Full Result
# 0          negative  {'model': 'phi3', 'created_at': '2024-09-21T17...
# 1             mixed  {'model': 'phi3', 'created_at': '2024-09-21T17...
# 2             mixed  {'model': 'phi3', 'created_at': '2024-09-21T17...
# 3             mixed  {'model': 'phi3', 'created_at': '2024-09-21T17...
# 4             mixed  {'model': 'phi3', 'created_at': '2024-09-21T17...
# ..              ...                                                ...
# 195           mixed  {'model': 'phi3', 'created_at': '2024-09-21T17...
# 196           mixed  {'model': 'phi3', 'created_at': '2024-09-21T17...
# 197        negative  {'model': 'phi3', 'created_at': '2024-09-21T17...
# 198           mixed  {'model': 'phi3', 'created_at': '2024-09-21T17...
# 199        negative  {'model': 'phi3', 'created_at': '2024-09-21T17...
#
# [200 rows x 4 columns]

# %%
# Read in file names in the folder C:\Users\MCOB PHD 14\Dropbox\Charlie's Dissertation\Beige Books\test_texts and save as a column in df_phi3 named "file_names""1970_ch (1)_chunk_4_sentiment_scores.csv"
import os
import pandas as pd

# Correctly formatted directory path
directory = r"C:\Users\MCOB PHD 14\Dropbox\Charlie's Dissertation\Beige Books\test_texts"

# List all txt files in the directory
file_list = [f for f in os.listdir(directory) if f.endswith('.txt')]

# Create a dataframe with the list of file names
df_phi3['file_names'] = file_list

# Display the dataframe
df_phi3.head()
# Out:
#    Document Number                                   Document Content  \
# 0                1  rates and terms have not eased much . There ar...
# 1                2  July 15 , 1970 Economic activity in the Fourth...
# 2                3  wage settlements and over continued upward pre...
# 3                4  adversely affected by curtailment of Governmen...
# 4                5  build offshore nuclear generators . Two wareho...
#
#   Sentiment Label                                        Full Result  \
# 0        negative  {'model': 'phi3', 'created_at': '2024-09-21T17...
# 1           mixed  {'model': 'phi3', 'created_at': '2024-09-21T17...
# 2           mixed  {'model': 'phi3', 'created_at': '2024-09-21T17...
# 3           mixed  {'model': 'phi3', 'created_at': '2024-09-21T17...
# 4           mixed  {'model': 'phi3', 'created_at': '2024-09-21T17...
#
#                  file_names
# 0   1970_ch (1)_chunk_4.txt
# 1   1970_cl (6)_chunk_1.txt
# 2   1970_ny (1)_chunk_3.txt
# 3  1971_kc (12)_chunk_2.txt
# 4   1972_at (9)_chunk_2.txt

# %%
# Load the sentiment scores CSV
excel_path = r"C:/Users/MCOB PHD 14/Dropbox/Charlie's Dissertation/Beige Books/manual_sentiment.csv"
human_df = pd.read_csv(excel_path)

# Define the label function
def label_sentiment(score):
    if score <= -0.3:
        return 0  # Negative
    elif score <= 0.2:
        return 1  # Mixed
    else:
        return 2  # Positive

# Apply the label function to the sentiment scores
human_df['label'] = human_df['human_sentiment'].apply(label_sentiment)

# convert label numbers to be negative, mixed, or positive
human_df['Human_Label'] = human_df['label'].replace({0: 'negative', 1: 'mixed', 2: 'positive'})

human_df.head()

# Merge the human sentiment labels with df_phi3 on file_names
merged_df = df_phi3.merge(human_df, how='inner', left_on='file_names', right_on='file_names')
merged_df.head()
# Out:
#    Document Number                                   Document Content  \
# 0                1  rates and terms have not eased much . There ar...
# 1                2  July 15 , 1970 Economic activity in the Fourth...
# 2                3  wage settlements and over continued upward pre...
# 3                4  adversely affected by curtailment of Governmen...
# 4                5  build offshore nuclear generators . Two wareho...
#
#   Sentiment Label                                        Full Result  \
# 0        negative  {'model': 'phi3', 'created_at': '2024-09-21T17...
# 1           mixed  {'model': 'phi3', 'created_at': '2024-09-21T17...
# 2           mixed  {'model': 'phi3', 'created_at': '2024-09-21T17...
# 3           mixed  {'model': 'phi3', 'created_at': '2024-09-21T17...
# 4           mixed  {'model': 'phi3', 'created_at': '2024-09-21T17...
#
#                  file_names  Document  human_sentiment scorer  label  \
# 0   1970_ch (1)_chunk_4.txt         3             -0.5     CS      0
# 1   1970_cl (6)_chunk_1.txt         6              0.3     CS      2
# 2   1970_ny (1)_chunk_3.txt        13             -0.2     CS      1
# 3  1971_kc (12)_chunk_2.txt        21              0.1     CS      1
# 4   1972_at (9)_chunk_2.txt        35              0.6     CS      2
#
#   Human_Label
# 0    negative
# 1    positive
# 2       mixed
# 3       mixed
# 4    positive

# %%
from sklearn.metrics import classification_report, accuracy_score

# Generate classification report
class_report = classification_report(merged_df['Human_Label'], merged_df['Sentiment Label'], labels=['positive', 'negative', 'mixed'])
print("\nClassification Report:")
print(class_report)

# Calculate and print accuracy
accuracy = accuracy_score(merged_df['Human_Label'], merged_df['Sentiment Label'])
print(f'Accuracy: {accuracy:.3f}')
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#     positive       0.93      0.36      0.52        78
#     negative       0.83      0.49      0.61        39
#        mixed       0.52      0.93      0.67        83
#
#     accuracy                           0.62       200
#    macro avg       0.76      0.59      0.60       200
# weighted avg       0.74      0.62      0.60       200
#
# Accuracy: 0.620

# %% [markdown]
# # Gemma 2

# %%
# Import necessary libraries
import json
import pandas as pd

# Set the local model and new prompt for classification
local_model = 'gemma2'
prompt_sentiment = 'Label the overall economic sentiment in the following Beige Book text as negative, mixed, or positive. Return the label as a JSON value with a key of "label" and nothing else: '

# Function to get sentiment label for each document
def get_sentiment_label(doc_content):
    # Combine the sentiment prompt with the document content
    full_prompt = f"{prompt_sentiment}\n{doc_content}"
    # Generate the sentiment label using the local model
    result = ollama.generate(model=local_model, prompt=full_prompt, format='json', stream=False, options={'temperature': 0})
    return result

# Possible keys that might hold the sentiment label
label_keys = ["label", "sentiment_label"]

# List to store the data for the DataFrame
data = []

# Total number of documents for progress tracking
total_docs = len(docs)

# Collect sentiment results for each document, with document index and status update
for i, doc in enumerate(docs):
    doc_content = doc.page_content
    result = get_sentiment_label(doc_content)
    
    # Extract the response value from the result
    response_json = result.get('response', '{}')
    # Parse the response JSON if it's a string
    response_data = json.loads(response_json) if isinstance(response_json, str) else response_json
    
    # Extract the sentiment label using the possible keys
    sentiment_label = None
    for key in label_keys:
        if key in response_data:
            sentiment_label = response_data[key]
            break
    
    # If no label was found, set it as 'N/A'
    if sentiment_label is None:
        sentiment_label = 'N/A'
    
    # Append the result to the data list with the document index and content
    data.append({
        "Document Number": i + 1,
        "Document Content": doc_content,
        "Sentiment Label": sentiment_label,
        "Full Result": result
    })

    # Print status update
    print(f"Processed document {i + 1}/{total_docs} - Sentiment Label: {sentiment_label}")

# Create a DataFrame from the data list
df_gemma2 = pd.DataFrame(data)

# Print the DataFrame
df_gemma2.head()
# Out:
# Processed document 1/200 - Sentiment Label: negative
# Processed document 2/200 - Sentiment Label: mixed
# Processed document 3/200 - Sentiment Label: mixed
# Processed document 4/200 - Sentiment Label: mixed
# Processed document 5/200 - Sentiment Label: mixed
# Processed document 6/200 - Sentiment Label: positive
# Processed document 7/200 - Sentiment Label: positive
# Processed document 8/200 - Sentiment Label: mixed
# Processed document 9/200 - Sentiment Label: mixed
# Processed document 10/200 - Sentiment Label: mixed
# Processed document 11/200 - Sentiment Label: negative
# Processed document 12/200 - Sentiment Label: mixed
# Processed document 13/200 - Sentiment Label: positive
# Processed document 14/200 - Sentiment Label: mixed
# Processed document 15/200 - Sentiment Label: negative
# Processed document 16/200 - Sentiment Label: mixed
# Processed document 17/200 - Sentiment Label: mixed
# Processed document 18/200 - Sentiment Label: mixed
# Processed document 19/200 - Sentiment Label: mixed
# Processed document 20/200 - Sentiment Label: negative
# Processed document 21/200 - Sentiment Label: mixed
# Processed document 22/200 - Sentiment Label: mixed
# Processed document 23/200 - Sentiment Label: mixed
# Processed document 24/200 - Sentiment Label: negative
# Processed document 25/200 - Sentiment Label: mixed
# Processed document 26/200 - Sentiment Label: mixed
# Processed document 27/200 - Sentiment Label: mixed
# Processed document 28/200 - Sentiment Label: mixed
# Processed document 29/200 - Sentiment Label: mixed
# Processed document 30/200 - Sentiment Label: mixed
# Processed document 31/200 - Sentiment Label: mixed
# Processed document 32/200 - Sentiment Label: negative
# Processed document 33/200 - Sentiment Label: mixed
# Processed document 34/200 - Sentiment Label: mixed
# Processed document 35/200 - Sentiment Label: negative
# Processed document 36/200 - Sentiment Label: negative
# Processed document 37/200 - Sentiment Label: mixed
# Processed document 38/200 - Sentiment Label: mixed
# Processed document 39/200 - Sentiment Label: mixed
# Processed document 40/200 - Sentiment Label: negative
# Processed document 41/200 - Sentiment Label: negative
# Processed document 42/200 - Sentiment Label: mixed
# Processed document 43/200 - Sentiment Label: positive
# Processed document 44/200 - Sentiment Label: mixed
# Processed document 45/200 - Sentiment Label: mixed
# Processed document 46/200 - Sentiment Label: mixed
# Processed document 47/200 - Sentiment Label: mixed
# Processed document 48/200 - Sentiment Label: mixed
# Processed document 49/200 - Sentiment Label: negative
# Processed document 50/200 - Sentiment Label: mixed
# Processed document 51/200 - Sentiment Label: negative
# Processed document 52/200 - Sentiment Label: mixed
# Processed document 53/200 - Sentiment Label: mixed
# Processed document 54/200 - Sentiment Label: mixed
# Processed document 55/200 - Sentiment Label: mixed
# Processed document 56/200 - Sentiment Label: negative
# Processed document 57/200 - Sentiment Label: mixed
# Processed document 58/200 - Sentiment Label: mixed
# Processed document 59/200 - Sentiment Label: mixed
# Processed document 60/200 - Sentiment Label: mixed
# Processed document 61/200 - Sentiment Label: mixed
# Processed document 62/200 - Sentiment Label: mixed
# Processed document 63/200 - Sentiment Label: positive
# Processed document 64/200 - Sentiment Label: mixed
# Processed document 65/200 - Sentiment Label: mixed
# Processed document 66/200 - Sentiment Label: mixed
# Processed document 67/200 - Sentiment Label: mixed
# Processed document 68/200 - Sentiment Label: mixed
# Processed document 69/200 - Sentiment Label: mixed
# Processed document 70/200 - Sentiment Label: mixed
# Processed document 71/200 - Sentiment Label: mixed
# Processed document 72/200 - Sentiment Label: mixed
# Processed document 73/200 - Sentiment Label: mixed
# Processed document 74/200 - Sentiment Label: mixed
# Processed document 75/200 - Sentiment Label: positive
# Processed document 76/200 - Sentiment Label: positive
# Processed document 77/200 - Sentiment Label: mixed
# Processed document 78/200 - Sentiment Label: positive
# Processed document 79/200 - Sentiment Label: mixed
# Processed document 80/200 - Sentiment Label: mixed
# Processed document 81/200 - Sentiment Label: mixed
# Processed document 82/200 - Sentiment Label: mixed
# Processed document 83/200 - Sentiment Label: positive
# Processed document 84/200 - Sentiment Label: positive
# Processed document 85/200 - Sentiment Label: mixed
# Processed document 86/200 - Sentiment Label: mixed
# Processed document 87/200 - Sentiment Label: mixed
# Processed document 88/200 - Sentiment Label: mixed
# Processed document 89/200 - Sentiment Label: mixed
# Processed document 90/200 - Sentiment Label: mixed
# Processed document 91/200 - Sentiment Label: mixed
# Processed document 92/200 - Sentiment Label: positive
# Processed document 93/200 - Sentiment Label: positive
# Processed document 94/200 - Sentiment Label: mixed
# Processed document 95/200 - Sentiment Label: mixed
# Processed document 96/200 - Sentiment Label: positive
# Processed document 97/200 - Sentiment Label: positive
# Processed document 98/200 - Sentiment Label: mixed
# Processed document 99/200 - Sentiment Label: mixed
# Processed document 100/200 - Sentiment Label: negative
# Processed document 101/200 - Sentiment Label: negative
# Processed document 102/200 - Sentiment Label: mixed
# Processed document 103/200 - Sentiment Label: mixed
# Processed document 104/200 - Sentiment Label: mixed
# Processed document 105/200 - Sentiment Label: mixed
# Processed document 106/200 - Sentiment Label: mixed
# Processed document 107/200 - Sentiment Label: mixed
# Processed document 108/200 - Sentiment Label: mixed
# Processed document 109/200 - Sentiment Label: mixed
# Processed document 110/200 - Sentiment Label: positive
# Processed document 111/200 - Sentiment Label: mixed
# Processed document 112/200 - Sentiment Label: mixed
# Processed document 113/200 - Sentiment Label: positive
# Processed document 114/200 - Sentiment Label: mixed
# Processed document 115/200 - Sentiment Label: positive
# Processed document 116/200 - Sentiment Label: mixed
# Processed document 117/200 - Sentiment Label: positive
# Processed document 118/200 - Sentiment Label: positive
# Processed document 119/200 - Sentiment Label: mixed
# Processed document 120/200 - Sentiment Label: mixed
# Processed document 121/200 - Sentiment Label: mixed
# Processed document 122/200 - Sentiment Label: mixed
# Processed document 123/200 - Sentiment Label: mixed
# Processed document 124/200 - Sentiment Label: mixed
# Processed document 125/200 - Sentiment Label: mixed
# Processed document 126/200 - Sentiment Label: mixed
# Processed document 127/200 - Sentiment Label: mixed
# Processed document 128/200 - Sentiment Label: mixed
# Processed document 129/200 - Sentiment Label: mixed
# Processed document 130/200 - Sentiment Label: mixed
# Processed document 131/200 - Sentiment Label: mixed
# Processed document 132/200 - Sentiment Label: negative
# Processed document 133/200 - Sentiment Label: mixed
# Processed document 134/200 - Sentiment Label: mixed
# Processed document 135/200 - Sentiment Label: mixed
# Processed document 136/200 - Sentiment Label: mixed
# Processed document 137/200 - Sentiment Label: mixed
# Processed document 138/200 - Sentiment Label: mixed
# Processed document 139/200 - Sentiment Label: mixed
# Processed document 140/200 - Sentiment Label: negative
# Processed document 141/200 - Sentiment Label: mixed
# Processed document 142/200 - Sentiment Label: mixed
# Processed document 143/200 - Sentiment Label: mixed
# Processed document 144/200 - Sentiment Label: mixed
# Processed document 145/200 - Sentiment Label: mixed
# Processed document 146/200 - Sentiment Label: mixed
# Processed document 147/200 - Sentiment Label: mixed
# Processed document 148/200 - Sentiment Label: mixed
# Processed document 149/200 - Sentiment Label: positive
# Processed document 150/200 - Sentiment Label: mixed
# Processed document 151/200 - Sentiment Label: mixed
# Processed document 152/200 - Sentiment Label: positive
# Processed document 153/200 - Sentiment Label: mixed
# Processed document 154/200 - Sentiment Label: positive
# Processed document 155/200 - Sentiment Label: mixed
# Processed document 156/200 - Sentiment Label: mixed
# Processed document 157/200 - Sentiment Label: mixed
# Processed document 158/200 - Sentiment Label: mixed
# Processed document 159/200 - Sentiment Label: mixed
# Processed document 160/200 - Sentiment Label: mixed
# Processed document 161/200 - Sentiment Label: mixed
# Processed document 162/200 - Sentiment Label: mixed
# Processed document 163/200 - Sentiment Label: negative
# Processed document 164/200 - Sentiment Label: mixed
# Processed document 165/200 - Sentiment Label: mixed
# Processed document 166/200 - Sentiment Label: mixed
# Processed document 167/200 - Sentiment Label: mixed
# Processed document 168/200 - Sentiment Label: mixed
# Processed document 169/200 - Sentiment Label: mixed
# Processed document 170/200 - Sentiment Label: positive
# Processed document 171/200 - Sentiment Label: mixed
# Processed document 172/200 - Sentiment Label: mixed
# Processed document 173/200 - Sentiment Label: mixed
# Processed document 174/200 - Sentiment Label: mixed
# Processed document 175/200 - Sentiment Label: mixed
# Processed document 176/200 - Sentiment Label: mixed
# Processed document 177/200 - Sentiment Label: positive
# Processed document 178/200 - Sentiment Label: mixed
# Processed document 179/200 - Sentiment Label: mixed
# Processed document 180/200 - Sentiment Label: mixed
# Processed document 181/200 - Sentiment Label: mixed
# Processed document 182/200 - Sentiment Label: mixed
# Processed document 183/200 - Sentiment Label: negative
# Processed document 184/200 - Sentiment Label: mixed
# Processed document 185/200 - Sentiment Label: mixed
# Processed document 186/200 - Sentiment Label: mixed
# Processed document 187/200 - Sentiment Label: mixed
# Processed document 188/200 - Sentiment Label: mixed
# Processed document 189/200 - Sentiment Label: mixed
# Processed document 190/200 - Sentiment Label: mixed
# Processed document 191/200 - Sentiment Label: mixed
# Processed document 192/200 - Sentiment Label: mixed
# Processed document 193/200 - Sentiment Label: mixed
# Processed document 194/200 - Sentiment Label: mixed
# Processed document 195/200 - Sentiment Label: mixed
# Processed document 196/200 - Sentiment Label: mixed
# Processed document 197/200 - Sentiment Label: mixed
# Processed document 198/200 - Sentiment Label: mixed
# Processed document 199/200 - Sentiment Label: mixed
# Processed document 200/200 - Sentiment Label: mixed
#    Document Number                                   Document Content  \
# 0                1  rates and terms have not eased much . There ar...
# 1                2  July 15 , 1970 Economic activity in the Fourth...
# 2                3  wage settlements and over continued upward pre...
# 3                4  adversely affected by curtailment of Governmen...
# 4                5  build offshore nuclear generators . Two wareho...
#
#   Sentiment Label                                        Full Result
# 0        negative  {'model': 'gemma2', 'created_at': '2024-09-21T...
# 1           mixed  {'model': 'gemma2', 'created_at': '2024-09-21T...
# 2           mixed  {'model': 'gemma2', 'created_at': '2024-09-21T...
# 3           mixed  {'model': 'gemma2', 'created_at': '2024-09-21T...
# 4           mixed  {'model': 'gemma2', 'created_at': '2024-09-21T...

# %%
import os
import pandas as pd

# Create a dataframe with the list of file names
df_gemma2['file_names'] = file_list

# Display the dataframe
df_gemma2.head()

# Rename Sentiment Label as Gemma2_sentiment
df_gemma2.rename(columns={'Sentiment Label': 'Gemma2_sentiment'}, inplace=True)

# Merge the human sentiment labels with df_gemma2 on file_names
merged_df = human_df.merge(df_gemma2, how='inner', on='file_names')

# %%
# Generate classification report
class_report = classification_report(merged_df['Human_Label'], merged_df['Gemma2_sentiment'], labels=['positive', 'negative', 'mixed'])
print("\nClassification Report:")
print(class_report)

# Calculate and print accuracy
accuracy = accuracy_score(merged_df['Human_Label'], merged_df['Gemma2_sentiment'])
print(f'Accuracy: {accuracy:.3f}')
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#     positive       0.96      0.29      0.45        78
#     negative       0.84      0.41      0.55        39
#        mixed       0.50      0.95      0.66        83
#
#     accuracy                           0.59       200
#    macro avg       0.77      0.55      0.55       200
# weighted avg       0.75      0.59      0.56       200
#
# Accuracy: 0.590

# %% [markdown]
# # Llama 3.1

# %%
# Import necessary libraries
import json
import pandas as pd

# Set the local model and new prompt for classification
local_model = 'llama3.1:latest'
prompt_sentiment = 'Label the overall economic sentiment in the following Beige Book text as negative, mixed, or positive. Return the label as a JSON value with a key of "label" and nothing else: '

# Function to get sentiment label for each document
def get_sentiment_label(doc_content):
    # Combine the sentiment prompt with the document content
    full_prompt = f"{prompt_sentiment}\n{doc_content}"
    # Generate the sentiment label using the local model
    result = ollama.generate(model=local_model, prompt=full_prompt, format='json', stream=False, options={'temperature': 0})
    return result

# Possible keys that might hold the sentiment label
label_keys = ["label", "sentiment_label"]

# List to store the data for the DataFrame
data = []

# Total number of documents for progress tracking
total_docs = len(docs)

# Collect sentiment results for each document, with document index and status update
for i, doc in enumerate(docs):
    doc_content = doc.page_content
    result = get_sentiment_label(doc_content)
    
    # Extract the response value from the result
    response_json = result.get('response', '{}')
    # Parse the response JSON if it's a string
    response_data = json.loads(response_json) if isinstance(response_json, str) else response_json
    
    # Extract the sentiment label using the possible keys
    sentiment_label = None
    for key in label_keys:
        if key in response_data:
            sentiment_label = response_data[key]
            break
    
    # If no label was found, set it as 'N/A'
    if sentiment_label is None:
        sentiment_label = 'N/A'
    
    # Append the result to the data list with the document index and content
    data.append({
        "Document Number": i + 1,
        "Document Content": doc_content,
        "Sentiment Label": sentiment_label,
        "Full Result": result
    })

    # Print status update
    print(f"Processed document {i + 1}/{total_docs} - Sentiment Label: {sentiment_label}")

# Create a DataFrame from the data list
df_llama = pd.DataFrame(data)

# Print the DataFrame
print(df_llama)
# Out:
# Processed document 1/200 - Sentiment Label: negative
# Processed document 2/200 - Sentiment Label: mixed
# Processed document 3/200 - Sentiment Label: mixed
# Processed document 4/200 - Sentiment Label: mixed
# Processed document 5/200 - Sentiment Label: mixed
# Processed document 6/200 - Sentiment Label: positive
# Processed document 7/200 - Sentiment Label: positive
# Processed document 8/200 - Sentiment Label: mixed
# Processed document 9/200 - Sentiment Label: mixed
# Processed document 10/200 - Sentiment Label: negative
# Processed document 11/200 - Sentiment Label: negative
# Processed document 12/200 - Sentiment Label: negative
# Processed document 13/200 - Sentiment Label: positive
# Processed document 14/200 - Sentiment Label: mixed
# Processed document 15/200 - Sentiment Label: negative
# Processed document 16/200 - Sentiment Label: mixed
# Processed document 17/200 - Sentiment Label: mixed
# Processed document 18/200 - Sentiment Label: positive
# Processed document 19/200 - Sentiment Label: negative
# Processed document 20/200 - Sentiment Label: negative
# Processed document 21/200 - Sentiment Label: mixed
# Processed document 22/200 - Sentiment Label: mixed
# Processed document 23/200 - Sentiment Label: positive
# Processed document 24/200 - Sentiment Label: negative
# Processed document 25/200 - Sentiment Label: mixed
# Processed document 26/200 - Sentiment Label: mixed
# Processed document 27/200 - Sentiment Label: mixed
# Processed document 28/200 - Sentiment Label: negative
# Processed document 29/200 - Sentiment Label: negative
# Processed document 30/200 - Sentiment Label: mixed
# Processed document 31/200 - Sentiment Label: mixed
# Processed document 32/200 - Sentiment Label: negative
# Processed document 33/200 - Sentiment Label: mixed
# Processed document 34/200 - Sentiment Label: mixed
# Processed document 35/200 - Sentiment Label: negative
# Processed document 36/200 - Sentiment Label: negative
# Processed document 37/200 - Sentiment Label: mixed
# Processed document 38/200 - Sentiment Label: mixed
# Processed document 39/200 - Sentiment Label: negative
# Processed document 40/200 - Sentiment Label: negative
# Processed document 41/200 - Sentiment Label: negative
# Processed document 42/200 - Sentiment Label: mixed
# Processed document 43/200 - Sentiment Label: positive
# Processed document 44/200 - Sentiment Label: mixed
# Processed document 45/200 - Sentiment Label: mixed
# Processed document 46/200 - Sentiment Label: mixed
# Processed document 47/200 - Sentiment Label: positive
# Processed document 48/200 - Sentiment Label: positive
# Processed document 49/200 - Sentiment Label: mixed
# Processed document 50/200 - Sentiment Label: negative
# Processed document 51/200 - Sentiment Label: negative
# Processed document 52/200 - Sentiment Label: mixed
# Processed document 53/200 - Sentiment Label: mixed
# Processed document 54/200 - Sentiment Label: mixed
# Processed document 55/200 - Sentiment Label: negative
# Processed document 56/200 - Sentiment Label: negative
# Processed document 57/200 - Sentiment Label: positive
# Processed document 58/200 - Sentiment Label: mixed
# Processed document 59/200 - Sentiment Label: mixed
# Processed document 60/200 - Sentiment Label: mixed
# Processed document 61/200 - Sentiment Label: mixed
# Processed document 62/200 - Sentiment Label: mixed
# Processed document 63/200 - Sentiment Label: positive
# Processed document 64/200 - Sentiment Label: positive
# Processed document 65/200 - Sentiment Label: mixed
# Processed document 66/200 - Sentiment Label: mixed
# Processed document 67/200 - Sentiment Label: mixed
# Processed document 68/200 - Sentiment Label: mixed
# Processed document 69/200 - Sentiment Label: mixed
# Processed document 70/200 - Sentiment Label: mixed
# Processed document 71/200 - Sentiment Label: mixed
# Processed document 72/200 - Sentiment Label: mixed
# Processed document 73/200 - Sentiment Label: mixed
# Processed document 74/200 - Sentiment Label: mixed
# Processed document 75/200 - Sentiment Label: positive
# Processed document 76/200 - Sentiment Label: positive
# Processed document 77/200 - Sentiment Label: mixed
# Processed document 78/200 - Sentiment Label: positive
# Processed document 79/200 - Sentiment Label: mixed
# Processed document 80/200 - Sentiment Label: mixed
# Processed document 81/200 - Sentiment Label: mixed
# Processed document 82/200 - Sentiment Label: mixed
# Processed document 83/200 - Sentiment Label: positive
# Processed document 84/200 - Sentiment Label: positive
# Processed document 85/200 - Sentiment Label: mixed
# Processed document 86/200 - Sentiment Label: mixed
# Processed document 87/200 - Sentiment Label: mixed
# Processed document 88/200 - Sentiment Label: positive
# Processed document 89/200 - Sentiment Label: negative
# Processed document 90/200 - Sentiment Label: positive
# Processed document 91/200 - Sentiment Label: mixed
# Processed document 92/200 - Sentiment Label: positive
# Processed document 93/200 - Sentiment Label: positive
# Processed document 94/200 - Sentiment Label: mixed
# Processed document 95/200 - Sentiment Label: positive
# Processed document 96/200 - Sentiment Label: positive
# Processed document 97/200 - Sentiment Label: positive
# Processed document 98/200 - Sentiment Label: mixed
# Processed document 99/200 - Sentiment Label: positive
# Processed document 100/200 - Sentiment Label: negative
# Processed document 101/200 - Sentiment Label: negative
# Processed document 102/200 - Sentiment Label: mixed
# Processed document 103/200 - Sentiment Label: mixed
# Processed document 104/200 - Sentiment Label: mixed
# Processed document 105/200 - Sentiment Label: mixed
# Processed document 106/200 - Sentiment Label: mixed
# Processed document 107/200 - Sentiment Label: mixed
# Processed document 108/200 - Sentiment Label: mixed
# Processed document 109/200 - Sentiment Label: mixed
# Processed document 110/200 - Sentiment Label: positive
# Processed document 111/200 - Sentiment Label: mixed
# Processed document 112/200 - Sentiment Label: mixed
# Processed document 113/200 - Sentiment Label: positive
# Processed document 114/200 - Sentiment Label: positive
# Processed document 115/200 - Sentiment Label: positive
# Processed document 116/200 - Sentiment Label: positive
# Processed document 117/200 - Sentiment Label: positive
# Processed document 118/200 - Sentiment Label: positive
# Processed document 119/200 - Sentiment Label: mixed
# Processed document 120/200 - Sentiment Label: mixed
# Processed document 121/200 - Sentiment Label: mixed
# Processed document 122/200 - Sentiment Label: mixed
# Processed document 123/200 - Sentiment Label: mixed
# Processed document 124/200 - Sentiment Label: mixed
# Processed document 125/200 - Sentiment Label: mixed
# Processed document 126/200 - Sentiment Label: mixed
# Processed document 127/200 - Sentiment Label: mixed
# Processed document 128/200 - Sentiment Label: mixed
# Processed document 129/200 - Sentiment Label: mixed
# Processed document 130/200 - Sentiment Label: mixed
# Processed document 131/200 - Sentiment Label: mixed
# Processed document 132/200 - Sentiment Label: negative
# Processed document 133/200 - Sentiment Label: mixed
# Processed document 134/200 - Sentiment Label: mixed
# Processed document 135/200 - Sentiment Label: mixed
# Processed document 136/200 - Sentiment Label: mixed
# Processed document 137/200 - Sentiment Label: mixed
# Processed document 138/200 - Sentiment Label: mixed
# Processed document 139/200 - Sentiment Label: mixed
# Processed document 140/200 - Sentiment Label: negative
# Processed document 141/200 - Sentiment Label: mixed
# Processed document 142/200 - Sentiment Label: mixed
# Processed document 143/200 - Sentiment Label: positive
# Processed document 144/200 - Sentiment Label: mixed
# Processed document 145/200 - Sentiment Label: mixed
# Processed document 146/200 - Sentiment Label: mixed
# Processed document 147/200 - Sentiment Label: mixed
# Processed document 148/200 - Sentiment Label: mixed
# Processed document 149/200 - Sentiment Label: positive
# Processed document 150/200 - Sentiment Label: mixed
# Processed document 151/200 - Sentiment Label: mixed
# Processed document 152/200 - Sentiment Label: positive
# Processed document 153/200 - Sentiment Label: mixed
# Processed document 154/200 - Sentiment Label: positive
# Processed document 155/200 - Sentiment Label: mixed
# Processed document 156/200 - Sentiment Label: mixed
# Processed document 157/200 - Sentiment Label: mixed
# Processed document 158/200 - Sentiment Label: mixed
# Processed document 159/200 - Sentiment Label: mixed
# Processed document 160/200 - Sentiment Label: mixed
# Processed document 161/200 - Sentiment Label: mixed
# Processed document 162/200 - Sentiment Label: positive
# Processed document 163/200 - Sentiment Label: mixed
# Processed document 164/200 - Sentiment Label: positive
# Processed document 165/200 - Sentiment Label: mixed
# Processed document 166/200 - Sentiment Label: positive
# Processed document 167/200 - Sentiment Label: mixed
# Processed document 168/200 - Sentiment Label: positive
# Processed document 169/200 - Sentiment Label: mixed
# Processed document 170/200 - Sentiment Label: positive
# Processed document 171/200 - Sentiment Label: mixed
# Processed document 172/200 - Sentiment Label: positive
# Processed document 173/200 - Sentiment Label: mixed
# Processed document 174/200 - Sentiment Label: mixed
# Processed document 175/200 - Sentiment Label: mixed
# Processed document 176/200 - Sentiment Label: mixed
# Processed document 177/200 - Sentiment Label: positive
# Processed document 178/200 - Sentiment Label: mixed
# Processed document 179/200 - Sentiment Label: mixed
# Processed document 180/200 - Sentiment Label: mixed
# Processed document 181/200 - Sentiment Label: mixed
# Processed document 182/200 - Sentiment Label: mixed
# Processed document 183/200 - Sentiment Label: negative
# Processed document 184/200 - Sentiment Label: mixed
# Processed document 185/200 - Sentiment Label: mixed
# Processed document 186/200 - Sentiment Label: mixed
# Processed document 187/200 - Sentiment Label: mixed
# Processed document 188/200 - Sentiment Label: mixed
# Processed document 189/200 - Sentiment Label: mixed
# Processed document 190/200 - Sentiment Label: mixed
# Processed document 191/200 - Sentiment Label: mixed
# Processed document 192/200 - Sentiment Label: mixed
# Processed document 193/200 - Sentiment Label: mixed
# Processed document 194/200 - Sentiment Label: mixed
# Processed document 195/200 - Sentiment Label: mixed
# Processed document 196/200 - Sentiment Label: mixed
# Processed document 197/200 - Sentiment Label: mixed
# Processed document 198/200 - Sentiment Label: negative
# Processed document 199/200 - Sentiment Label: mixed
# Processed document 200/200 - Sentiment Label: mixed
#      Document Number                                   Document Content  \
# 0                  1  rates and terms have not eased much . There ar...
# 1                  2  July 15 , 1970 Economic activity in the Fourth...
# 2                  3  wage settlements and over continued upward pre...
# 3                  4  adversely affected by curtailment of Governmen...
# 4                  5  build offshore nuclear generators . Two wareho...
# ..               ...                                                ...
# 195              196  with several Florida ports reporting strong pa...
# 196              197  Beige Book Report : Dallas May 29 , 2024 Summa...
# 197              198  to the sidelines , diving up demand for rental...
# 198              199  significant discounts '' after a long period o...
# 199              200  to the industrial and multifamily segments . C...
#
#     Sentiment Label                                        Full Result
# 0          negative  {'model': 'llama3.1:latest', 'created_at': '20...
# 1             mixed  {'model': 'llama3.1:latest', 'created_at': '20...
# 2             mixed  {'model': 'llama3.1:latest', 'created_at': '20...
# 3             mixed  {'model': 'llama3.1:latest', 'created_at': '20...
# 4             mixed  {'model': 'llama3.1:latest', 'created_at': '20...
# ..              ...                                                ...
# 195           mixed  {'model': 'llama3.1:latest', 'created_at': '20...
# 196           mixed  {'model': 'llama3.1:latest', 'created_at': '20...
# 197        negative  {'model': 'llama3.1:latest', 'created_at': '20...
# 198           mixed  {'model': 'llama3.1:latest', 'created_at': '20...
# 199           mixed  {'model': 'llama3.1:latest', 'created_at': '20...
#
# [200 rows x 4 columns]

# %%
df_llama['file_names'] = file_list

# Rename Sentiment Label as Llama_sentiment
df_llama.rename(columns={'Sentiment Label': 'Llama_sentiment'}, inplace=True)

# Merge the human sentiment labels with df_llama on file_names
merged_df = human_df.merge(df_llama, how='inner', on='file_names')

# Generate classification report
class_report = classification_report(merged_df['Human_Label'], merged_df['Llama_sentiment'], labels=['positive', 'negative', 'mixed'])
print("\nClassification Report:")
print(class_report)

# Calculate and print accuracy
accuracy = accuracy_score(merged_df['Human_Label'], merged_df['Llama_sentiment'])
print(f'Accuracy: {accuracy:.3f}')
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#     positive       0.88      0.47      0.62        78
#     negative       0.85      0.59      0.70        39
#        mixed       0.57      0.90      0.70        83
#
#     accuracy                           0.68       200
#    macro avg       0.77      0.66      0.67       200
# weighted avg       0.75      0.68      0.67       200
#
# Accuracy: 0.675

# %%
merged_df.head()
# Out:
#    Document                file_names  human_sentiment scorer  label  \
# 0         3   1970_ch (1)_chunk_4.txt             -0.5     CS      0
# 1         6   1970_cl (6)_chunk_1.txt              0.3     CS      2
# 2        13   1970_ny (1)_chunk_3.txt             -0.2     CS      1
# 3        21  1971_kc (12)_chunk_2.txt              0.1     CS      1
# 4        35   1972_at (9)_chunk_2.txt              0.6     CS      2
#
#   Human_Label  Document Number  \
# 0    negative                1
# 1    positive                2
# 2       mixed                3
# 3       mixed                4
# 4    positive                5
#
#                                     Document Content Llama_sentiment  \
# 0  rates and terms have not eased much . There ar...        negative
# 1  July 15 , 1970 Economic activity in the Fourth...           mixed
# 2  wage settlements and over continued upward pre...           mixed
# 3  adversely affected by curtailment of Governmen...           mixed
# 4  build offshore nuclear generators . Two wareho...           mixed
#
#                                          Full Result
# 0  {'model': 'llama3.1:latest', 'created_at': '20...
# 1  {'model': 'llama3.1:latest', 'created_at': '20...
# 2  {'model': 'llama3.1:latest', 'created_at': '20...
# 3  {'model': 'llama3.1:latest', 'created_at': '20...
# 4  {'model': 'llama3.1:latest', 'created_at': '20...

# %%
merged_df['Sentiment_Phi3'] = df_phi3['Sentiment Label']
merged_df['Sentiment_Gemma2'] = df_gemma2['Gemma2_sentiment']

# Export merged_df to a CSV file
#merged_df.to_csv('open_source_LLMs_classification.csv', index=False)
# Out:
#    Document                file_names  human_sentiment scorer  label  \
# 0         3   1970_ch (1)_chunk_4.txt             -0.5     CS      0
# 1         6   1970_cl (6)_chunk_1.txt              0.3     CS      2
# 2        13   1970_ny (1)_chunk_3.txt             -0.2     CS      1
# 3        21  1971_kc (12)_chunk_2.txt              0.1     CS      1
# 4        35   1972_at (9)_chunk_2.txt              0.6     CS      2
#
#   Human_Label  Document Number  \
# 0    negative                1
# 1    positive                2
# 2       mixed                3
# 3       mixed                4
# 4    positive                5
#
#                                     Document Content Llama_sentiment  \
# 0  rates and terms have not eased much . There ar...        negative
# 1  July 15 , 1970 Economic activity in the Fourth...           mixed
# 2  wage settlements and over continued upward pre...           mixed
# 3  adversely affected by curtailment of Governmen...           mixed
# 4  build offshore nuclear generators . Two wareho...           mixed
#
#                                          Full Result Sentiment_Phi3
# 0  {'model': 'llama3.1:latest', 'created_at': '20...       negative
# 1  {'model': 'llama3.1:latest', 'created_at': '20...          mixed
# 2  {'model': 'llama3.1:latest', 'created_at': '20...          mixed
# 3  {'model': 'llama3.1:latest', 'created_at': '20...          mixed
# 4  {'model': 'llama3.1:latest', 'created_at': '20...          mixed

# %%
merged_df.head()
# Out:
#    Document                file_names  human_sentiment scorer  label  \
# 0         3   1970_ch (1)_chunk_4.txt             -0.5     CS      0
# 1         6   1970_cl (6)_chunk_1.txt              0.3     CS      2
# 2        13   1970_ny (1)_chunk_3.txt             -0.2     CS      1
# 3        21  1971_kc (12)_chunk_2.txt              0.1     CS      1
# 4        35   1972_at (9)_chunk_2.txt              0.6     CS      2
#
#   Human_Label  Document Number  \
# 0    negative                1
# 1    positive                2
# 2       mixed                3
# 3       mixed                4
# 4    positive                5
#
#                                     Document Content Llama_sentiment  \
# 0  rates and terms have not eased much . There ar...        negative
# 1  July 15 , 1970 Economic activity in the Fourth...           mixed
# 2  wage settlements and over continued upward pre...           mixed
# 3  adversely affected by curtailment of Governmen...           mixed
# 4  build offshore nuclear generators . Two wareho...           mixed
#
#                                          Full Result Sentiment_Phi3  \
# 0  {'model': 'llama3.1:latest', 'created_at': '20...       negative
# 1  {'model': 'llama3.1:latest', 'created_at': '20...          mixed
# 2  {'model': 'llama3.1:latest', 'created_at': '20...          mixed
# 3  {'model': 'llama3.1:latest', 'created_at': '20...          mixed
# 4  {'model': 'llama3.1:latest', 'created_at': '20...          mixed
#
#   Sentiment_Gemma2
# 0         negative
# 1            mixed
# 2            mixed
# 3            mixed
# 4            mixed

# %%
# Do separate class reports for each model
class_report_phi3 = classification_report(merged_df['Human_Label'], merged_df['Sentiment_Phi3'], labels=['positive', 'negative', 'mixed'])
class_report_gemma2 = classification_report(merged_df['Human_Label'], merged_df['Sentiment_Gemma2'], labels=['positive', 'negative', 'mixed'])
class_report_llama = classification_report(merged_df['Human_Label'], merged_df['Llama_sentiment'], labels=['positive', 'negative', 'mixed'])

# Print the classification reports
print("\nClassification Report for Phi3:")
print(class_report_phi3)
print("\nClassification Report for Gemma2:")
print(class_report_gemma2)
print("\nClassification Report for Llama:")
print(class_report_llama)
# Out:
# Classification Report for Phi3:
#               precision    recall  f1-score   support
#
#     positive       0.93      0.36      0.52        78
#     negative       0.83      0.49      0.61        39
#        mixed       0.52      0.93      0.67        83
#
#     accuracy                           0.62       200
#    macro avg       0.76      0.59      0.60       200
# weighted avg       0.74      0.62      0.60       200
#
#
# Classification Report for Gemma2:
#               precision    recall  f1-score   support
#
#     positive       0.96      0.29      0.45        78
#     negative       0.84      0.41      0.55        39
#        mixed       0.50      0.95      0.66        83
#
#     accuracy                           0.59       200
#    macro avg       0.77      0.55      0.55       200
# weighted avg       0.75      0.59      0.56       200
#
#
# Classification Report for Llama:
#               precision    recall  f1-score   support
#
#     positive       0.88      0.47      0.62        78
#     negative       0.85      0.59      0.70        39
#        mixed       0.57      0.90      0.70        83
#
#     accuracy                           0.68       200
#    macro avg       0.77      0.66      0.67       200
# weighted avg       0.75      0.68      0.67       200
