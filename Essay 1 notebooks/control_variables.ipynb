# %% [markdown]
# # Population by Fed District

# %% [markdown]
# This file contains code to obtain data by Federal Reserve district for:
# 1. Population (annual since 1970)
# 2. Unemployment (monthly, 1990-2015)
# 3. Job levels (monthly, 1990-present)

# %%
# Setting up FRED access
import pandas as pd
from fredapi import Fred
api_key = "b40f40a14d67c7903b44700db6b7b6e7"
fred = Fred(api_key=api_key)

# %%
# Giving the FRED series IDs for population for each of the 12 Fed districts
frb_series_ids_pop = [
    "D1POP", "D2POP", "D3POP", "D4POP", "D5POP", "D6POP",
    "D7POP", "D8POP", "D9POP", "D10POP", "D11POP", "D12POP"
    ]
frb_ids_pop = pd.DataFrame([frb_series_ids_pop])

# Blank dataframe setup
frb_pop = pd.DataFrame()

# %%
# Loop to download data for each state
for series_id in frb_series_ids_pop:
    frb_data_pop = fred.get_series(series_id)
    frb_pop = pd.concat([frb_pop, frb_data_pop], axis = 1)

# %%
# Rename columns by state
frb_pop.columns = frb_series_ids_pop
frb_pop.tail()

#Export to CSV
#frb_pop.to_csv("frb_pop.csv")
# Out:
#                          D1POP      D2POP      D3POP      D4POP      D5POP  \
# 2019-01-01 00:00:00  13905.274  26511.491  13323.775  17049.976  32627.504
# 2020-01-01 00:00:00  14115.143  27419.765  13596.615  17212.970  32712.201
# 2021-01-01 00:00:00  14156.098  27160.760  13650.138  17166.181  32902.547
# 2022-01-01 00:00:00  14170.757  26962.749  13654.551  17137.097  33123.822
# 2023-01-01 00:00:00  14208.219  26880.474  13682.232  17153.833  33412.114
#
#                          D6POP      D7POP      D8POP     D9POP     D10POP  \
# 2019-01-01 00:00:00  47838.758  34777.256  14791.437  9524.669  18544.311
# 2020-01-01 00:00:00  48256.354  35126.596  14787.291  9657.192  18652.648
# 2021-01-01 00:00:00  48595.341  35015.826  14795.556  9689.177  18716.324
# 2022-01-01 00:00:00  49211.078  34935.650  14799.527  9724.822  18779.955
# 2023-01-01 00:00:00  49800.601  34962.488  14830.385  9777.696  18879.442
#
#                         D11POP     D12POP
# 2019-01-01 00:00:00  30629.306  68758.891
# 2020-01-01 00:00:00  30883.711  69059.868
# 2021-01-01 00:00:00  31199.904  68954.917
# 2022-01-01 00:00:00  31657.411  69068.300
# 2023-01-01 00:00:00  32126.022  69155.967

# %%
# Calculate change in population from the previous year
frb_pop_change = frb_pop.pct_change()

# Rename columns as D1POP_change, D2POP_change, etc.
frb_pop_change.columns = [f"{col}_change" for col in frb_pop_change.columns]

# Merge the original population data with the change in population data
frb_pop_change = pd.concat([frb_pop, frb_pop_change], axis = 1)

# Export as CSV
#frb_pop_change.to_csv("Fed_District_population.csv")

# %%
# This is all for adding the population data to the BB data, which is not as easy as it seems!
    # See the file Beige Book classification models.ypynb for where I read this in
    # I'm just storing here so it won't jumble up that file

# read in bbNoText.csv as bbSimple
bbSimple = pd.read_csv("bbNoText.csv")

# Replace Nan with 0
bbSimple.fillna(0, inplace=True)

# Change Date to datetime format
bbSimple['Date'] = pd.to_datetime(bbSimple['Date'])

# Read in population data by Fed district
pop = pd.read_csv("frb_pop.csv")

# Set Date as datetime
pop['Date'] = pd.to_datetime(pop['Date'])

# Add rows for every month in the data starting on the first of the month
# Include the same population number for each month within a year
pop = pop.set_index('Date').resample('MS').ffill().reset_index()

# Assuming 2024 is same as 2023 because we don't have data for 2024
# Drop 2025 data, which was just included to make it fill in all months for 2024
pop = pop[pop['Date'].dt.year < 2025]

# Join bbSimple and pop while keeping all data in bbSimple
bbSimple = pd.merge(bbSimple, pop, on=['Date'], how='left')

# Sum the population for each district into a new column called D13POP
bbSimple['D13POP'] = bbSimple['D01POP'] + bbSimple['D02POP'] + bbSimple['D03POP'] + bbSimple['D04POP'] + bbSimple['D05POP'] + bbSimple['D06POP'] + bbSimple['D07POP'] + bbSimple['D08POP'] + bbSimple['D09POP'] + bbSimple['D10POP'] + bbSimple['D11POP'] + bbSimple['D12POP']

# For DO1POP to D12POP, want to place the values into a new column called 'Population' based on the District number
# Create a dictionary to map the District number to the column name
pop_dict = {'D01POP': '1', 'D02POP': '2', 'D03POP': '3', 'D04POP': '4', 'D05POP': '5', 'D06POP': '6', 'D07POP': '7', 'D08POP': '8', 'D09POP': '9', 'D10POP': '10', 'D11POP': '11', 'D12POP': '12', 'D13POP': '13'}

# Loop through the dictionary and place the values into the 'Population' column
for key, value in pop_dict.items():
    bbSimple.loc[bbSimple['District'] == int(value), 'population'] = bbSimple[key]

# Drop the columns that are no longer needed
bbSimple.drop(columns=['D01POP', 'D02POP', 'D03POP', 'D04POP', 'D05POP', 'D06POP', 'D07POP', 'D08POP', 'D09POP', 'D10POP', 'D11POP', 'D12POP','D13POP'], inplace=True)

# Export to csv
#bbSimple.to_csv("bbNoText_pop.csv")

# %%
# This calculates percent change in population from the previous year for each district
    # Not using it for now but leaving it here in case want to use later
# For each month, look up the year, then calculate the percent change in population from the previous year for that distict
bbSimple['year'] = bbSimple['Date'].dt.year
bbSimple['prev_year'] = bbSimple['year'] - 1

# Create a new column for the previous year's population
bbSimple['prev_year_pop'] = bbSimple['population'].shift(12)

# Calculate the percent change in population from the previous year
bbSimple['pop_change'] = (bbSimple['population'] - bbSimple['prev_year_pop']) / bbSimple['prev_year_pop']

# Drop the columns that are no longer needed
bbSimple.drop(columns=['year', 'prev_year', 'prev_year_pop'], inplace=True)

# %% [markdown]
# # Unemployment Rate by Fed District

# %% [markdown]
# Dataset available 1990 - 2015

# %%
# Giving the FRED series IDs for unemployment rate each of the 50 states
    # Doing this in case I decide to use unemployment rate as a DV
frb_series_ids = [
    "D1URN", "D2URN", "D3URN", "D4URN", "D5URN", "D6URN",
    "D7URN", "D8URN", "D9URN", "D10URN", "D11URN", "D12URN"
    ]
frb_ids = pd.DataFrame([frb_series_ids])

# %%
frb_ur = pd.DataFrame()

# Loop to download data for each Fed district
for series_id in frb_series_ids:
    frb_data = fred.get_series(series_id)
    frb_ur = pd.concat([frb_ur, frb_data], axis = 1)

# %%
# Rename columns by district
frb_ur.columns = frb_series_ids
frb_ur.head()
# Out:
#                      D1URN  D2URN  D3URN  D4URN  D5URN  D6URN  D7URN  D8URN  \
# 1990-01-01 00:00:00  5.682  5.544  5.612  6.772  4.707  6.002  6.784  6.973
# 1990-02-01 00:00:00  5.745  5.555  5.599  6.301  4.573  5.867  6.515  7.126
# 1990-03-01 00:00:00  5.654  5.172  5.231  5.694  4.071  5.473  6.202  6.545
# 1990-04-01 00:00:00  5.440  4.878  4.892  5.796  4.028  5.554  5.756  6.154
# 1990-05-01 00:00:00  5.442  4.851  4.955  5.460  4.237  5.569  5.509  5.951
#
#                      D9URN  D10URN  D11URN  D12URN
# 1990-01-01 00:00:00  5.713   5.671   6.636   5.724
# 1990-02-01 00:00:00  5.709   5.316   6.625   5.668
# 1990-03-01 00:00:00  5.673   5.037   6.161   5.416
# 1990-04-01 00:00:00  5.093   4.656   6.137   5.276
# 1990-05-01 00:00:00  4.372   4.622   6.167   5.052

# %%
frb_ur.tail()
# This data is not seasonally adjusted
# Federal Reserve Bank of Dallas has employment levels data going back to 1990 that is still updated
# Out:
#                      D1URN  D2URN  D3URN  D4URN  D5URN  D6URN  D7URN  D8URN  \
# 2015-07-01 00:00:00  4.873  5.546  6.008  5.288  5.742  6.102  5.338  5.987
# 2015-08-01 00:00:00  4.547  5.078  5.579  4.642  5.478  5.779  4.842  5.262
# 2015-09-01 00:00:00  4.389  4.907  5.063  4.521  5.096  5.563  4.415  4.957
# 2015-10-01 00:00:00  4.279  4.599  4.797  4.338  5.120  5.384  4.596  4.833
# 2015-11-01 00:00:00  4.384  4.681  4.629  4.551  4.985  5.118  4.674  4.918
#
#                      D9URN  D10URN  D11URN  D12URN
# 2015-07-01 00:00:00  3.814   4.612   4.718   6.153
# 2015-08-01 00:00:00  3.490   4.346   4.516   5.857
# 2015-09-01 00:00:00  3.203   3.884   4.492   5.371
# 2015-10-01 00:00:00  3.055   3.844   4.607   5.446
# 2015-11-01 00:00:00  3.181   3.821   4.648   5.440

# %% [markdown]
# # Jobs by Fed district

# %%
# Dallas Fed posts updated Excel file each month at this length
    # Data goes back to 1990
read_url = "https://www.dallasfed.org/~/media/documents/research/econdata//emp12dist/emp12dist.xlsx"

# %%
# Read in data from Excel file

emp12dist = pd.read_excel(read_url, sheet_name = "12distsa", skiprows = 3, index_col = 0)

# %%
# Going to rename columns to match other data by District
new_column_names = {col: f'D{i}_jobs' for i, col in enumerate(emp12dist.columns, start=1)}

emp12dist.rename(columns=new_column_names, inplace=True)
emp12dist.head()
# Out:
#            D1_jobs  D2_jobs D3_jobs D4_jobs  D5_jobs  D6_jobs  D7_jobs  \
# Date
# 1990-01-01  6056.2  11350.1  5178.8  6875.4  10961.1  13350.9  13980.7
# 1990-02-01  6043.3  11346.6  5187.1  6904.6  11002.3  13378.7  14046.5
# 1990-03-01  6041.8    11349    5195  6924.3  11028.6  13411.5  14079.4
# 1990-04-01  6001.5    11288  5164.8  6930.2  11010.5    13402  14061.3
# 1990-05-01  5992.9  11301.6  5163.3    6943  11024.6  13440.3    14082
#
#            D8_jobs D9_jobs D10_jobs D11_jobs D12_jobs
# Date
# 1990-01-01  5207.5  3354.4     5794   7467.7  19726.3
# 1990-02-01  5205.1  3361.2     5808   7478.9  19757.4
# 1990-03-01  5212.3    3364   5820.9   7499.8  19790.9
# 1990-04-01  5209.3  3370.4   5828.2   7522.5  19841.1
# 1990-05-01  5220.2  3377.4     5853     7565  19883.6

# %% [markdown]
# Data available from FRED by counties:
# 1. Per capita personal income (since 1969) - PCPI is the code, followed by 5-digit GEOID
#     Example: Autauga County, AL: https://fred.stlouisfed.org/series/PCPI01001, GEOID from FedCounties is 1001
#         Might need to add that leading 0 to the counties that only have 4 digits
#
# 2. Percent below the poverty line (annual, since 1989) - S1701ACS followed by 6-digit GEOID
#     Autauga, AL: https://fred.stlouisfed.org/series/S1701ACS001001
#
# 3. Unemployment rate (monthly, since 1990)
#     Autauga, Al: https://fred.stlouisfed.org/series/ALAUTA1URN
#     Baldwin County, Al: https://fred.stlouisfed.org/series/ALBALD0URN
#
# 4. Civilian labor force (monthly, since 1990)
#     Autauga, AL: https://fred.stlouisfed.org/series/ALAUTA1LFN
#
# 5. House Price Index (annual, since 1975)
#     Big counties only, e.g. Mobile County - https://fred.stlouisfed.org/series/ATNHPIUS01097A\
#
# 6. SNAP benefits recipients (annual, since 1989)
#     Autauga, AL: https://fred.stlouisfed.org/series/CBR01001ALA647NCEN

# %% [markdown]
# # County listing by Fed District

# %% [markdown]
# Source: Tousey, Colton. 2019. Data files for the paper "Federal Reserve District County Shapefiles." Federal Reserve Bank of Kansas City, Technical Briefing no. 19-01. Available at https://www.kansascityfed.org/publications/research/technicalbriefings/articles/2019/0417-district-county-shapefiles

# %%
import pandas as pd
FedCounties = pd.read_csv('FedCounties.csv', encoding='latin1')

# %%
# Add one leading zero to GEOID if it only has 4 characters and make it a string
FedCounties['GEOID'] = FedCounties['GEOID'].apply(lambda x: str(x).zfill(5))

# add "PCPI" to beginning of each GEOID
FedCounties['GEOID'] = FedCounties['GEOID'].apply(lambda x: "PCPI" + x)

# %%
# This takes a long time to loop through all the series IDs: 35 minutes in my case

frb_pcpi = pd.DataFrame()

for series_id in FedCounties['GEOID']:
    try:
        frb_data_pcpi = fred.get_series(series_id)
        frb_pcpi = pd.concat([frb_pcpi, frb_data_pcpi], axis=1)
    except Exception as e:
        print(f"Error occurred while processing series ID {series_id}: {e}")
        continue
# Out:
# Error occurred while processing series ID PCPI02158: Bad Request.  The series does not exist.
# Error occurred while processing series ID PCPI15005: Bad Request.  The series does not exist.
# Error occurred while processing series ID PCPI15009: Bad Request.  The series does not exist.
# Error occurred while processing series ID PCPI51003: Bad Request.  The series does not exist.
# Error occurred while processing series ID PCPI51005: Bad Request.  The series does not exist.
# Error occurred while processing series ID PCPI51015: Bad Request.  The series does not exist.
# Error occurred while processing series ID PCPI51031: Bad Request.  The series does not exist.
# Error occurred while processing series ID PCPI51035: Bad Request.  The series does not exist.
# Error occurred while processing series ID PCPI51053: Bad Request.  The series does not exist.
# Error occurred while processing series ID PCPI51059: Bad Request.  The series does not exist.
# Error occurred while processing series ID PCPI51069: Bad Request.  The series does not exist.
# Error occurred while processing series ID PCPI51081: Bad Request.  The series does not exist.
# Error occurred while processing series ID PCPI51089: Bad Request.  The series does not exist.
# Error occurred while processing series ID PCPI51095: Bad Request.  The series does not exist.
# Error occurred while processing series ID PCPI51121: Bad Request.  The series does not exist.
# Error occurred while processing series ID PCPI51143: Bad Request.  The series does not exist.
# Error occurred while processing series ID PCPI51149: Bad Request.  The series does not exist.
# Error occurred while processing series ID PCPI51153: Bad Request.  The series does not exist.
# Error occurred while processing series ID PCPI51161: Bad Request.  The series does not exist.
# Error occurred while processing series ID PCPI51163: Bad Request.  The series does not exist.
# Error occurred while processing series ID PCPI51165: Bad Request.  The series does not exist.
# Error occurred while processing series ID PCPI51175: Bad Request.  The series does not exist.
# Error occurred while processing series ID PCPI51177: Bad Request.  The series does not exist.
# Error occurred while processing series ID PCPI51191: Bad Request.  The series does not exist.
# Error occurred while processing series ID PCPI51195: Bad Request.  The series does not exist.
# Error occurred while processing series ID PCPI51199: Bad Request.  The series does not exist.
# Error occurred while processing series ID PCPI51520: Bad Request.  The series does not exist.
# Error occurred while processing series ID PCPI51530: Bad Request.  The series does not exist.
# Error occurred while processing series ID PCPI51540: Bad Request.  The series does not exist.
# Error occurred while processing series ID PCPI51570: Bad Request.  The series does not exist.
# Error occurred while processing series ID PCPI51580: Bad Request.  The series does not exist.
# Error occurred while processing series ID PCPI51590: Bad Request.  The series does not exist.
# Error occurred while processing series ID PCPI51595: Bad Request.  The series does not exist.
# Error occurred while processing series ID PCPI51600: Bad Request.  The series does not exist.
# Error occurred while processing series ID PCPI51610: Bad Request.  The series does not exist.
# Error occurred while processing series ID PCPI51620: Bad Request.  The series does not exist.
# Error occurred while processing series ID PCPI51630: Bad Request.  The series does not exist.
# Error occurred while processing series ID PCPI51640: Bad Request.  The series does not exist.
# Error occurred while processing series ID PCPI51660: Bad Request.  The series does not exist.
# Error occurred while processing series ID PCPI51670: Bad Request.  The series does not exist.
# Error occurred while processing series ID PCPI51678: Bad Request.  The series does not exist.
# Error occurred while processing series ID PCPI51680: Bad Request.  The series does not exist.
# Error occurred while processing series ID PCPI51683: Bad Request.  The series does not exist.
# Error occurred while processing series ID PCPI51685: Bad Request.  The series does not exist.
# Error occurred while processing series ID PCPI51690: Bad Request.  The series does not exist.
# Error occurred while processing series ID PCPI51720: Bad Request.  The series does not exist.
# Error occurred while processing series ID PCPI51730: Bad Request.  The series does not exist.
# Error occurred while processing series ID PCPI51735: Bad Request.  The series does not exist.
# Error occurred while processing series ID PCPI51750: Bad Request.  The series does not exist.
# Error occurred while processing series ID PCPI51775: Bad Request.  The series does not exist.
# Error occurred while processing series ID PCPI51790: Bad Request.  The series does not exist.
# Error occurred while processing series ID PCPI51820: Bad Request.  The series does not exist.
# Error occurred while processing series ID PCPI51830: Bad Request.  The series does not exist.
# Error occurred while processing series ID PCPI51840: Bad Request.  The series does not exist.
# Error occurred while processing series ID PCPI60010: Bad Request.  The series does not exist.
# Error occurred while processing series ID PCPI60020: Bad Request.  The series does not exist.
# Error occurred while processing series ID PCPI60030: Bad Request.  The series does not exist.
# Error occurred while processing series ID PCPI60040: Bad Request.  The series does not exist.
# Error occurred while processing series ID PCPI60050: Bad Request.  The series does not exist.
# Error occurred while processing series ID PCPI66010: Bad Request.  The series does not exist.
# Error occurred while processing series ID PCPI69085: Bad Request.  The series does not exist.
# Error occurred while processing series ID PCPI69100: Bad Request.  The series does not exist.
# Error occurred while processing series ID PCPI69110: Bad Request.  The series does not exist.
# Error occurred while processing series ID PCPI69120: Bad Request.  The series does not exist.
# Error occurred while processing series ID PCPI72001: Bad Request.  The series does not exist.
# Error occurred while processing series ID PCPI72003: Bad Request.  The series does not exist.
# Error occurred while processing series ID PCPI72005: Bad Request.  The series does not exist.
# Error occurred while processing series ID PCPI72007: Bad Request.  The series does not exist.
# Error occurred while processing series ID PCPI72009: Bad Request.  The series does not exist.
# Error occurred while processing series ID PCPI72011: Bad Request.  The series does not exist.
# Error occurred while processing series ID PCPI72013: Bad Request.  The series does not exist.
# Error occurred while processing series ID PCPI72015: Bad Request.  The series does not exist.
# Error occurred while processing series ID PCPI72017: Bad Request.  The series does not exist.
# Error occurred while processing series ID PCPI72019: Bad Request.  The series does not exist.
# Error occurred while processing series ID PCPI72021: Bad Request.  The series does not exist.
# Error occurred while processing series ID PCPI72023: Bad Request.  The series does not exist.
# Error occurred while processing series ID PCPI72025: Bad Request.  The series does not exist.
# Error occurred while processing series ID PCPI72027: Bad Request.  The series does not exist.
# Error occurred while processing series ID PCPI72029: Bad Request.  The series does not exist.
# Error occurred while processing series ID PCPI72031: Bad Request.  The series does not exist.
# Error occurred while processing series ID PCPI72033: Bad Request.  The series does not exist.
# Error occurred while processing series ID PCPI72035: Bad Request.  The series does not exist.
# Error occurred while processing series ID PCPI72037: Bad Request.  The series does not exist.
# Error occurred while processing series ID PCPI72039: Bad Request.  The series does not exist.
# Error occurred while processing series ID PCPI72041: Bad Request.  The series does not exist.
# Error occurred while processing series ID PCPI72043: Bad Request.  The series does not exist.
# Error occurred while processing series ID PCPI72045: Bad Request.  The series does not exist.
# Error occurred while processing series ID PCPI72047: Bad Request.  The series does not exist.
# Error occurred while processing series ID PCPI72049: Bad Request.  The series does not exist.
# Error occurred while processing series ID PCPI72051: Bad Request.  The series does not exist.
# Error occurred while processing series ID PCPI72053: Bad Request.  The series does not exist.
# Error occurred while processing series ID PCPI72054: Bad Request.  The series does not exist.
# Error occurred while processing series ID PCPI72055: Bad Request.  The series does not exist.
# Error occurred while processing series ID PCPI72057: Bad Request.  The series does not exist.
# Error occurred while processing series ID PCPI72059: Bad Request.  The series does not exist.
# Error occurred while processing series ID PCPI72061: Bad Request.  The series does not exist.
# Error occurred while processing series ID PCPI72063: Bad Request.  The series does not exist.
# Error occurred while processing series ID PCPI72065: Bad Request.  The series does not exist.
# Error occurred while processing series ID PCPI72067: Bad Request.  The series does not exist.
# Error occurred while processing series ID PCPI72069: Bad Request.  The series does not exist.
# Error occurred while processing series ID PCPI72071: Bad Request.  The series does not exist.
# Error occurred while processing series ID PCPI72073: Bad Request.  The series does not exist.
# Error occurred while processing series ID PCPI72075: Bad Request.  The series does not exist.
# Error occurred while processing series ID PCPI72077: Bad Request.  The series does not exist.
# Error occurred while processing series ID PCPI72079: Bad Request.  The series does not exist.
# Error occurred while processing series ID PCPI72081: Bad Request.  The series does not exist.
# Error occurred while processing series ID PCPI72083: Bad Request.  The series does not exist.
# Error occurred while processing series ID PCPI72085: Bad Request.  The series does not exist.
# Error occurred while processing series ID PCPI72087: Bad Request.  The series does not exist.
# Error occurred while processing series ID PCPI72089: Bad Request.  The series does not exist.
# Error occurred while processing series ID PCPI72091: Bad Request.  The series does not exist.
# Error occurred while processing series ID PCPI72093: Bad Request.  The series does not exist.
# Error occurred while processing series ID PCPI72095: Bad Request.  The series does not exist.
# Error occurred while processing series ID PCPI72097: Bad Request.  The series does not exist.
# Error occurred while processing series ID PCPI72099: Bad Request.  The series does not exist.
# Error occurred while processing series ID PCPI72101: Bad Request.  The series does not exist.
# Error occurred while processing series ID PCPI72103: Bad Request.  The series does not exist.
# Error occurred while processing series ID PCPI72105: Bad Request.  The series does not exist.
# Error occurred while processing series ID PCPI72107: Bad Request.  The series does not exist.
# Error occurred while processing series ID PCPI72109: Bad Request.  The series does not exist.
# Error occurred while processing series ID PCPI72111: Bad Request.  The series does not exist.
# Error occurred while processing series ID PCPI72113: Bad Request.  The series does not exist.
# Error occurred while processing series ID PCPI72115: Bad Request.  The series does not exist.
# Error occurred while processing series ID PCPI72117: Bad Request.  The series does not exist.
# Error occurred while processing series ID PCPI72119: Bad Request.  The series does not exist.
# Error occurred while processing series ID PCPI72121: Bad Request.  The series does not exist.
# Error occurred while processing series ID PCPI72123: Bad Request.  The series does not exist.
# Error occurred while processing series ID PCPI72125: Bad Request.  The series does not exist.
# Error occurred while processing series ID PCPI72127: Bad Request.  The series does not exist.
# Error occurred while processing series ID PCPI72129: Bad Request.  The series does not exist.
# Error occurred while processing series ID PCPI72131: Bad Request.  The series does not exist.
# Error occurred while processing series ID PCPI72133: Bad Request.  The series does not exist.
# Error occurred while processing series ID PCPI72135: Bad Request.  The series does not exist.
# Error occurred while processing series ID PCPI72137: Bad Request.  The series does not exist.
# Error occurred while processing series ID PCPI72139: Bad Request.  The series does not exist.
# Error occurred while processing series ID PCPI72141: Bad Request.  The series does not exist.
# Error occurred while processing series ID PCPI72143: Bad Request.  The series does not exist.
# Error occurred while processing series ID PCPI72145: Bad Request.  The series does not exist.
# Error occurred while processing series ID PCPI72147: Bad Request.  The series does not exist.
# Error occurred while processing series ID PCPI72149: Bad Request.  The series does not exist.
# Error occurred while processing series ID PCPI72151: Bad Request.  The series does not exist.
# Error occurred while processing series ID PCPI72153: Bad Request.  The series does not exist.
# Error occurred while processing series ID PCPI78010: Bad Request.  The series does not exist.
# Error occurred while processing series ID PCPI78020: Bad Request.  The series does not exist.
# Error occurred while processing series ID PCPI78030: Bad Request.  The series does not exist.

# %%
# Read in list of 145 bad_pcpi_ids
    # These are the series IDs that returned an error when trying to download data
    # Good explanations for most of these errors:
    # Name change in Alaska, small counties in Hawaii, Virginia cities, in Guam and other U.S. territories, etc.
bad_pcpi_ids = pd.read_csv('bad_pcpi_ids.csv',  header= None)

# %%
# Remove bad series IDs from FedCounties
FedCounties2 = FedCounties[~FedCounties['GEOID'].isin(bad_pcpi_ids[0])]

# %%
# Rename columns in frb_pcpi to match FedCounties2 GEOIDs
frb_pcpi.columns = FedCounties2['GEOID'][:len(frb_pcpi.columns)]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 2
#       1 # Rename columns in frb_pcpi to match FedCounties2 GEOIDs
# ----> 2 frb_pcpi.columns = FedCounties2['GEOID'][:len(frb_pcpi.columns)]
#
# NameError: name 'frb_pcpi' is not defined

# %%
# save frb_pcpi to CSV
frb_pcpi.to_csv('frb_pcpi.csv', index = True)

# %%
# Can use list of good ids to download other county datasets from FRED

# Don't download the PCPI data again; it's annual so doesn't update frequently
    # And takes forever to download

# But do unemployment next

# %% [markdown]
# # County-level data

# %%
import pandas as pd
countyIncome = pd.read_csv('frb_pcpi.csv')

# Reshape countyIncome to long format
countyIncome_long = countyIncome.melt(id_vars=['Unnamed: 0'], var_name='GEOID', value_name='PCPI')

# Rename the 'Unnamed: 0' column to 'Date' for better readability
countyIncome_long.rename(columns={'Unnamed: 0': 'Date'}, inplace=True)

# Change to date-time format
countyIncome_long['Date'] = pd.to_datetime(countyIncome_long['Date'])

# Merge the two datasets on the 'GEOID' column
merged_data = pd.merge(countyIncome_long, FedCounties2, on='GEOID', how='left')

# Group by 'Date' and 'District' and calculate the average PCPI
average_pcpi_per_district = merged_data.groupby(['Date', 'District'])['PCPI'].mean().reset_index()

# Display the first few rows of the result
print(average_pcpi_per_district.head())

# Save the result to a new CSV file
#average_pcpi_per_district.to_csv('path/to/average_pcpi_per_district.csv', index=False)
# Out:
#         Date  District         PCPI
# 0 1969-01-01         1  3703.651515
# 1 1969-01-01         2  3925.093333
# 2 1969-01-01         3  3615.633333
# 3 1969-01-01         4  3054.674556
# 4 1969-01-01         5  2842.814570

# %%
# Get federal poverty guidelines for family of four
# Source: https://aspe.hhs.gov/topics/poverty-economic-mobility/poverty-guidelines/prior-hhs-poverty-guidelines-federal-register-references
poverty = pd.read_csv('poverty.csv')

# change to date-time format for year only
poverty['Date'] = pd.to_datetime(poverty['Date'], format='%Y')

# Join poverty and merged_data on 'Date'
poverty_merged = pd.merge(poverty, merged_data, on='Date', how='left')

# Calculate the percentage of the federal poverty level
poverty_merged['FPL'] = poverty_merged['PCPI'] / poverty_merged['Poverty']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\MCOB PHD 14\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File c:\Users\MCOB PHD 14\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\MCOB PHD 14\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Poverty'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[19], line 12
#       9 poverty_merged = pd.merge(poverty, merged_data, on='Date', how='left')
#      11 # Calculate the percentage of the federal poverty level
# ---> 12 poverty_merged['FPL'] = poverty_merged['PCPI'] / poverty_merged['Poverty']
#
# File c:\Users\MCOB PHD 14\anaconda3\Lib\site-packages\pandas\core\frame.py:3761, in DataFrame.__getitem__(self, key)
#    3759 if self.columns.nlevels > 1:
#    3760     return self._getitem_multilevel(key)
# -> 3761 indexer = self.columns.get_loc(key)
#    3762 if is_integer(indexer):
#    3763     indexer = [indexer]
#
# File c:\Users\MCOB PHD 14\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3655, in Index.get_loc(self, key)
#    3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
# -> 3655     raise KeyError(key) from err
#    3656 except TypeError:
#    3657     # If we have a listlike key, _check_indexing_error will raise
#    3658     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3659     #  the TypeError.
#    3660     self._check_indexing_error(key)
#
# KeyError: 'Poverty'

# %%
poverty_merged.tail()
# Out:
#              Date  poverty_threshold      GEOID     PCPI     FID  STATEFP  \
# 166751 2022-01-01              27750  PCPI56041  44775.0   120.0     56.0
# 166752 2022-01-01              27750  PCPI56043  55288.0   600.0     56.0
# 166753 2022-01-01              27750  PCPI56045  50987.0  2120.0     56.0
# 166754 2023-01-01              30000        NaN      NaN     NaN      NaN
# 166755 2024-01-01              31200        NaN      NaN     NaN      NaN
#
#         COUNTYFP   COUNTYNS      NAME         NAMELSAD  ...  METDIVFP  \
# 166751      41.0  1605084.0     Uinta     Uinta County  ...
# 166752      43.0  1605085.0  Washakie  Washakie County  ...
# 166753      45.0  1605086.0    Weston    Weston County  ...
# 166754       NaN        NaN       NaN              NaN  ...       NaN
# 166755       NaN        NaN       NaN              NaN  ...       NaN
#
#        FUNCSTAT         ALAND      AWATER   INTPTLAT    INTPTLON  GEOID_1  \
# 166751        A  5.391632e+09  16625817.0  41.284726 -110.558947  56041.0
# 166752        A  5.798139e+09  10429604.0  43.878830 -107.669052  56043.0
# 166753        A  6.210804e+09   5225499.0  43.846213 -104.570020  56045.0
# 166754      NaN           NaN         NaN        NaN         NaN      NaN
# 166755      NaN           NaN         NaN        NaN         NaN      NaN
#
#         District       PovertyID  Below_poverty
# 166751      10.0  S1701ACS056041          False
# 166752      10.0  S1701ACS056043          False
# 166753      10.0  S1701ACS056045          False
# 166754       NaN             NaN          False
# 166755       NaN             NaN          False
#
# [5 rows x 25 columns]

# %%
# Count proportion of counties in each district that are below the poverty line
poverty_merged['Below_poverty'] = poverty_merged['PCPI'] < poverty_merged['poverty_threshold']

# Group by 'Date' and 'District' and calculate the proportion of counties below the poverty line
poverty_proportion = poverty_merged.groupby(['Date', 'District'])['Below_poverty'].mean().reset_index()

# Display the first few rows of the result
print(poverty_proportion.head())
# Out:
#         Date  District  Below_poverty
# 0 1969-01-01       1.0       0.439394
# 1 1969-01-01       2.0       0.426667
# 2 1969-01-01       3.0       0.500000
# 3 1969-01-01       4.0       0.739645
# 4 1969-01-01       5.0       0.864238

# %%
FedCounties2.head()

# Create a new column called PovertyID that we will fill in later
FedCounties2['PovertyID'] = 'S1701ACS0' + FedCounties2['GEOID'].str[-5:]

# Setting up FRED access
import pandas as pd
from fredapi import Fred
api_key = "b40f40a14d67c7903b44700db6b7b6e7"
fred = Fred(api_key=api_key)
# Out:
# C:\Users\MCOB PHD 14\AppData\Local\Temp\ipykernel_13992\2454260172.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   FedCounties2['PovertyID'] = 'S1701ACS0' + FedCounties2['GEOID'].str[-5:]

# %%
frb_pov = pd.DataFrame()

for series_id in FedCounties2['PovertyID']:
    try:
        frb_data_pov = fred.get_series(series_id)
        frb_pov = pd.concat([frb_pov, frb_data_pov], axis=1)
    except Exception as e:
        print(f"Error occurred while processing series ID {series_id}: {e}")
        continue
# Out:
# Error occurred while processing series ID S1701ACS006093: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS006095: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS006097: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS006099: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS006101: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS006103: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS012079: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS012081: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS012083: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS012085: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS012086: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS012087: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS012089: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS012091: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS012093: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS012095: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS012097: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS012099: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS012101: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS013213: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS013215: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS013217: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS013219: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS013221: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS013223: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS013225: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS017051: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS017053: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS017055: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS017057: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS017059: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS017061: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS017063: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS017065: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS017067: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS017069: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS017071: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS017073: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS018111: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS018113: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS018115: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS018117: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS018119: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS018121: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS018123: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS018125: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS019183: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS019185: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS019187: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS021021: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS021023: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS021025: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS021027: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS021029: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS021031: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS021033: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS021035: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS021037: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS021039: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS022041: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS022043: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS022045: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS022047: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS022049: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS022051: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS022053: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS022055: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS022057: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS026063: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS026065: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS026067: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS026069: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS026071: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS026073: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS026075: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS026077: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS026079: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS027155: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS027157: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS027159: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS027161: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS029065: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS029067: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS029069: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS030081: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS030083: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS030085: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS030087: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS032033: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS036111: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS036113: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS036115: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS038033: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS038035: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS038037: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS038039: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS038041: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS038043: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS040003: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS040005: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS040007: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS040009: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS040011: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS040013: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS040015: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS040017: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS040019: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS040021: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS040023: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS042039: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS042041: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS042043: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS042045: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS042047: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS042049: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS042051: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS042053: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS042055: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS042057: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS042059: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS046067: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS046069: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS046071: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS046073: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS046075: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS046077: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS046079: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS046081: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS046102: Bad Request.  The series does not exist.
# Error occurred while processing series ID S1701ACS047189: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS048001: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS048003: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS048005: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS048007: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS048009: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS048011: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS048013: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS048015: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS048017: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS048019: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS048261: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS048263: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS048265: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS048267: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS048269: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS048271: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS048273: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS048275: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS048277: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS048279: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS048281: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS049015: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS049017: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS049019: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS049021: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS049023: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS049025: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS049027: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS049029: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS049031: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS049033: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS049035: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS053027: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS053029: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS053031: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS055083: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS055085: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS055087: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS055089: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS055091: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS055093: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS055095: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS055097: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS055099: Too Many Requests.  Exceeded Rate Limit
# Error occurred while processing series ID S1701ACS055101: Too Many Requests.  Exceeded Rate Limit

# %%
countyIncome_long
# Out:
#                        Date      GEOID     PCPI
# 0       1969-01-01 00:00:00  PCPI01001   2780.0
# 1       1970-01-01 00:00:00  PCPI01001   3158.0
# 2       1971-01-01 00:00:00  PCPI01001   3454.0
# 3       1972-01-01 00:00:00  PCPI01001   3687.0
# 4       1973-01-01 00:00:00  PCPI01001   4039.0
# ...                     ...        ...      ...
# 166747  2018-01-01 00:00:00  PCPI56045  44657.0
# 166748  2019-01-01 00:00:00  PCPI56045  45546.0
# 166749  2020-01-01 00:00:00  PCPI56045  49854.0
# 166750  2021-01-01 00:00:00  PCPI56045  49734.0
# 166751  2022-01-01 00:00:00  PCPI56045  50987.0
#
# [166752 rows x 3 columns]
