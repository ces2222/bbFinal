# %% [markdown]
# # Descriptive Statistics

# %% [markdown]
# This file provides descriptive statistics and visualizations of the main variables.

# %%
import pandas as pd

# %%
bb = pd.read_csv('bbNoText.csv')

# %%
bb.describe()
# Out:
#               Year     District   econ_index  econ_index_levels       USPHCI  \
# count  4242.000000  4242.000000  4242.000000        4242.000000  4242.000000
# mean   2000.900519     6.500943     1.989022          87.870464    85.881443
# std      12.772214     3.450888     5.834020          26.618277    25.915295
# min    1979.000000     1.000000   -20.980000          40.640000    46.370000
# 25%    1990.000000     4.000000    -2.140000          64.915000    64.050000
# 50%    2001.000000     6.500000     0.600000          88.035000    88.700000
# 75%    2012.000000     9.000000     6.267500         103.027500   102.850000
# max    2023.000000    12.000000    23.890000         161.490000   138.240000
#
#        econ_index_dummy  compound_score  mean_sentiment  median_sentiment  \
# count       4242.000000     4242.000000     4242.000000       4242.000000
# mean           0.550212        0.864181        0.127853          0.089875
# std            0.497531        0.452598        0.081771          0.120031
# min            0.000000       -0.998400       -0.197844         -0.270000
# 25%            0.000000        0.987200        0.075606          0.000000
# 50%            1.000000        0.996200        0.132182          0.000000
# 75%            1.000000        0.998300        0.182429          0.177900
# max            1.000000        0.999900        0.401186          0.526700
#
#        IQR_sentiment  sentiment_trigram
# count    4242.000000        4242.000000
# mean        0.443621           0.123576
# std         0.107984           0.166468
# min         0.000000          -0.695000
# 25%         0.381800           0.000000
# 50%         0.440400           0.112766
# 75%         0.509800           0.236796
# max         0.994250           0.704417

# %%
# sort by 'District' and 'Year'
bb_sorted = bb.sort_values(by=['District', 'Year'])

# Selecting columns I want stats for
selected_columns = ['econ_index', 'econ_index_levels', 'compound_score', 'mean_sentiment', 'median_sentiment', 'IQR_sentiment', 'sentiment_trigram']
# Descriptive statistics by District
district_stats = bb_sorted.groupby('District')[selected_columns].describe()

# Descriptive statistics by Year
year_stats = bb_sorted.groupby('Year')[selected_columns].describe()

# %%
bb_sorted.groupby('District')['econ_index_levels'].describe()
# Out:
#           count       mean        std    min      25%     50%       75%  \
# District
# 1         352.0  87.952528  29.221105  46.59  62.0400  87.155  104.4800
# 2         354.0  88.378927  21.555933  56.19  70.8700  88.435  100.2700
# 3         353.0  88.168215  20.069850  54.54  71.7700  90.310  100.1900
# 4         354.0  89.764859  19.849321  54.86  74.2725  92.155  101.2900
# 5         354.0  86.641384  28.517321  45.51  62.8600  86.185  104.2450
# 6         354.0  85.868531  29.855930  43.86  60.5175  84.780  103.2125
# 7         354.0  89.739011  20.404968  53.89  73.4325  92.305  100.1650
# 8         353.0  88.981785  22.700743  52.94  70.0500  91.090  102.0700
# 9         354.0  88.486921  27.651509  47.53  64.8575  88.175  106.6700
# 10        353.0  87.727904  27.173307  49.70  63.9200  87.380  105.5200
# 11        354.0  87.197119  33.700017  40.64  57.0350  84.410  111.9150
# 12        353.0  85.535836  33.380723  40.67  58.3100  82.570  103.7300
#
#              max
# District
# 1         156.38
# 2         135.55
# 3         130.44
# 4         131.22
# 5         149.58
# 6         152.89
# 7         131.70
# 8         136.83
# 9         147.89
# 10        145.70
# 11        161.23
# 12        161.49

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming your DataFrame is named 'bb' and has a 'Date' column
# and a 'District' column among others

# Sort the DataFrame by the 'Date' column
bb_sorted_by_date = bb.sort_values(by='Date')

# Set the plotting style (optional, but can enhance visual appeal)
sns.set(style="whitegrid")

# Create a time series plot for each district
plt.figure(figsize=(14, 8))
sns.lineplot(x='Date', y='econ_index_levels', hue='District', data=bb_sorted_by_date)
plt.title('Time Series Plot of Economic Index Levels by District')
plt.xlabel('Date')
plt.ylabel('Economic Index Levels')
plt.legend(title='District', loc='upper left', bbox_to_anchor=(1, 1))
plt.show()

# %%
# Print or use the resulting DataFrames as needed
print("Descriptive Statistics by District:")
print(district_stats)
# Out:
# Descriptive Statistics by District:
#          econ_index                                                            \
#               count      mean       std    min     25%    50%      75%    max
# District
# 1             352.0  1.938835  5.053444 -12.24 -0.8525  0.315   3.1825  18.14
# 2             354.0  2.546695  5.237715 -20.98 -0.8250  0.805   8.1750  11.54
# 3             353.0  2.228385  6.222225 -18.44 -3.0400  1.900   7.7200  11.79
# 4             354.0  3.932627  6.678119 -15.99 -2.2675  5.005  10.0425  16.14
# 5             354.0  0.809153  3.345896  -3.15 -1.2200 -0.480   1.4725  11.34
# 6             354.0  0.036299  4.699060  -3.99 -2.7900 -2.220   0.5075  14.65
# 7             354.0  3.906780  6.571178 -19.63 -2.3425  4.795  10.0425  15.80
# 8             353.0  3.041530  3.772731  -6.99 -0.5300  2.140   6.5200  10.93
# 9             354.0  2.654689  3.029284  -8.35  0.7700  1.940   3.9025  12.11
# 10            353.0  1.808895  2.492047  -1.82 -0.3300  1.170   3.6900   8.69
# 11            354.0  1.364887  8.659141  -8.00 -5.0200 -3.050   9.1125  22.99
# 12            353.0 -0.404419  8.444640  -6.96 -5.9400 -5.470   0.8800  23.89
#
#          econ_index_levels             ... IQR_sentiment            \
#                      count       mean  ...           75%       max
# District                               ...
# 1                    352.0  87.952528  ...      0.493900  0.879575
# 2                    354.0  88.378927  ...      0.510600  0.803300
# 3                    353.0  88.168215  ...      0.487375  0.678550
# 4                    354.0  89.764859  ...      0.508581  0.790550
# 5                    354.0  86.641384  ...      0.484744  0.758600
# 6                    354.0  85.868531  ...      0.533706  0.783000
# 7                    354.0  89.739011  ...      0.511500  0.801700
# 8                    353.0  88.981785  ...      0.462900  0.694700
# 9                    354.0  88.486921  ...      0.468231  0.871800
# 10                   353.0  87.727904  ...      0.501200  0.740000
# 11                   354.0  87.197119  ...      0.534500  0.808500
# 12                   353.0  85.535836  ...      0.571100  0.994250
#
#          sentiment_trigram                                                    \
#                      count      mean       std       min       25%       50%
# District
# 1                    352.0  0.111351  0.151683 -0.367400  0.000000  0.095358
# 2                    354.0  0.061847  0.174596 -0.475700 -0.026379  0.026208
# 3                    353.0  0.169811  0.153519 -0.352967  0.007133  0.160128
# 4                    354.0  0.113509  0.162623 -0.489067  0.000000  0.077308
# 5                    354.0  0.130764  0.168510 -0.477833  0.000000  0.129742
# 6                    354.0  0.156613  0.175011 -0.340400  0.000000  0.165942
# 7                    354.0  0.151454  0.179753 -0.477700  0.000000  0.144814
# 8                    353.0  0.133095  0.162900 -0.695000  0.000000  0.126792
# 2003              96.0  0.143484  0.171251 -0.220200  0.000000  0.161468
# 2004              96.0  0.183044  0.164573 -0.367400  0.062554  0.192658
# 2005              96.0  0.214532  0.156429 -0.057600  0.090163  0.207800
# 2006              96.0  0.163330  0.133234 -0.189456  0.086525  0.174687
# 2007              96.0  0.138489  0.134793 -0.286833  0.027995  0.149677
# 2008              96.0  0.045241  0.147374 -0.288478 -0.038833  0.033470
# 2009              96.0  0.012665  0.142955 -0.371313 -0.059647  0.012213
# 2010              96.0  0.082636  0.150207 -0.477833  0.000425  0.096778
# 2011              96.0  0.084948  0.154217 -0.340600 -0.016693  0.095179
# 2012              96.0  0.216150  0.158394 -0.255211  0.126999  0.232039
# 2013              96.0  0.238617  0.139249 -0.183167  0.168847  0.240408
# 2014              96.0  0.228901  0.130365 -0.116800  0.151487  0.218528
# 2015              96.0  0.217046  0.118759 -0.277200  0.161604  0.227592
# 2016              96.0  0.181835  0.143362 -0.240033  0.094737  0.187582
# 2017              96.0  0.174107  0.129308 -0.191033  0.085524  0.178977
# 2018              96.0  0.196055  0.137356 -0.109980  0.109650  0.189269
# 2019              96.0  0.158305  0.151473 -0.196144  0.071290  0.162475
# 2020              96.0  0.079856  0.148935 -0.291867 -0.001080  0.068431
# 2021              96.0  0.153767  0.153962 -0.305700  0.064865  0.151817
# 2022              96.0  0.144044  0.136256 -0.158947  0.047783  0.161222
# 2023              48.0  0.127274  0.136699 -0.131467  0.037740  0.137227
#
#
#            75%       max
# Year
# 1979  0.145237  0.614567
# 1980  0.103315  0.651667
# 1981  0.029450  0.439000
# 1982  0.000000  0.555850
# 1983  0.142858  0.483500
# 1984  0.277647  0.530133
# 1985  0.208400  0.548200
# 1986  0.205181  0.466033
# 1987  0.199146  0.544867
# 1988  0.212037  0.644633
# 1989  0.216000  0.580000
# 1990  0.135372  0.489700
# 1991  0.139762  0.515833
# 1992  0.203522  0.633067
# 1993  0.184100  0.597633
# 1994  0.337189  0.576767
# 1995  0.249348  0.704417
# 1996  0.209804  0.514628
# 1997  0.263966  0.622200
# 1998  0.220219  0.538233
# 1999  0.245017  0.555100
# 2000  0.281212  0.542233
# 2001  0.211567  0.558400
# 2002  0.191642  0.361733
# 2003  0.267317  0.590300
# 2004  0.298205  0.539000
# 2005  0.333107  0.559929
# 2006  0.259873  0.438750
# 2007  0.217207  0.455462
# 2008  0.136667  0.442967
# 2009  0.095188  0.358724
# 2010  0.165524  0.502967
# 2011  0.193363  0.484333
# 2012  0.332900  0.507200
# 2013  0.340265  0.564767
# 2014  0.316304  0.544100
# 2015  0.287925  0.456473
# 2016  0.287161  0.490783
# 2017  0.268345  0.414267
# 2018  0.291117  0.544750
# 2019  0.257915  0.524233
# 2020  0.165780  0.481025
# 2021  0.249302  0.569100
# 2022  0.224492  0.417683
# 2023  0.203406  0.575267
#
# [45 rows x 56 columns]

# %%
predictors = ['compound_score', 'mean_sentiment', 'median_sentiment', 'IQR_sentiment', 'sentiment_trigram']
DVs = ['USPHCI', 'econ_index_dummy', 'econ_index', 'econ_index_levels']

# %%
bb[predictors].describe()
# Out:
#        compound_score  mean_sentiment  median_sentiment  IQR_sentiment  \
# count     4242.000000     4242.000000       4242.000000    4242.000000
# mean         0.864181        0.127853          0.089875       0.443621
# std          0.452598        0.081771          0.120031       0.107984
# min         -0.998400       -0.197844         -0.270000       0.000000
# 25%          0.987200        0.075606          0.000000       0.381800
# 50%          0.996200        0.132182          0.000000       0.440400
# 75%          0.998300        0.182429          0.177900       0.509800
# max          0.999900        0.401186          0.526700       0.994250
#
#        sentiment_trigram
# count        4242.000000
# mean            0.123576
# std             0.166468
# min            -0.695000
# 25%             0.000000
# 50%             0.112766
# 75%             0.236796
# max             0.704417

# %%
import matplotlib.pyplot as plt

# Plot a histogram for the 'mean_sentiment' column
plt.hist(bb['mean_sentiment'], bins=30, color='blue', alpha=0.7)
plt.title('Histogram of Mean Sentiment at the sentence level')
plt.xlabel('Mean Sentiment')
plt.ylabel('Frequency')
plt.show()

# %%
# Plot a histogram for the 'mean_sentiment' column
plt.hist(bb['median_sentiment'], bins=30, color='blue', alpha=0.7)
plt.title('Histogram of Median Sentiment at the sentence level')
plt.xlabel('Median Sentiment')
plt.ylabel('Frequency')
plt.show()

# %%
# Count the occurrences where 'median_sentiment' is equal to 0
count_median_sentiment_zero = (bb['median_sentiment'] == 0).sum()

# Print the result
print(f"The number of times 'median_sentiment' equals 0 is: {count_median_sentiment_zero}")
# Out:
# The number of times 'median_sentiment' equals 0 is: 2300

# %%
# Count the occurrences where 'trigram' is equal to 0
count_sentiment_trigram_zero = (bb['sentiment_trigram'] == 0).sum()

# Print the result
print(f"The number of times none of the 43 key trigrams are found in the document is: {count_sentiment_trigram_zero}")

print((4202-803)/4202)
print(4202-803)
# Out:
# The number of times none of the 43 key trigrams are found in the document is: 803
# 0.8089005235602095
# 3399

# %%
# Plot a histogram for the 'compound_score' column
plt.hist(bb['compound_score'], bins=30, color='blue', alpha=0.7)
plt.title('Histogram of Compound Sentiment at the document level')
plt.xlabel('Mean Sentiment')
plt.ylabel('Frequency')
plt.show()

# %%
# Plot a histogram for the 'sentiment_trigram' column
plt.hist(bb['sentiment_trigram'], bins=30, color='blue', alpha=0.7)
plt.title('Histogram of Trigram Sentiment at the document level')
plt.xlabel('Trigram Sentiment')
plt.ylabel('Frequency')
plt.show()

# %%
correlation_predictors = ['compound_score', 'mean_sentiment', 'median_sentiment', 'IQR_sentiment', 'sentiment_trigram']

# Create a correlation matrix
correlation_table = bb[correlation_predictors].corr()

# Print or display the correlation table
print("Correlation Table:")
print(correlation_table)
# Out:
# Correlation Table:
#                    compound_score  mean_sentiment  median_sentiment  \
# compound_score           1.000000        0.590132          0.239836
# mean_sentiment           0.590132        1.000000          0.772093
# median_sentiment         0.239836        0.772093          1.000000
# IQR_sentiment           -0.041783        0.134564          0.239733
# sentiment_trigram        0.265948        0.463177          0.359533
#
#                    IQR_sentiment  sentiment_trigram
# compound_score         -0.041783           0.265948
# mean_sentiment          0.134564           0.463177
# median_sentiment        0.239733           0.359533
# IQR_sentiment           1.000000           0.077471
# sentiment_trigram       0.077471           1.000000
